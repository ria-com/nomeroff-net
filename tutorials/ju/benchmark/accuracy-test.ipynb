# %% [markdown]
# # Start to end test

# %%
import os
import warnings
import matplotlib.pyplot as plt
from glob import glob
from _paths import nomeroff_net_dir

from nomeroff_net import pipeline
from nomeroff_net.tools import unzip

warnings.filterwarnings("ignore")

# %% [markdown]
# Before runing this test, please download models from [https://nomeroff.net.ua/models/](https://nomeroff.net.ua/models/) to **./models/** directory.

# %%
number_plate_detection_and_reading = pipeline("number_plate_detection_and_reading", image_loader="turbo")

# %% [markdown]
# # Oneline numberplate

# %%
image_paths = glob(os.path.join(nomeroff_net_dir, "./data/examples/benchmark_oneline_np_images/*"))
result = number_plate_detection_and_reading(image_paths, quality_profile=[3, 1, 0])
# Out:
# 	Tile 1/1
# 	Tile 1/1

# %%
(images, images_bboxs, 
 images_points, images_zones, region_ids, 
 region_names, count_lines, 
 confidences, texts) = unzip(result)

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,10)

# %%
number_plate_detection_and_reading.text_accuracy_test_from_file(
    os.path.join(nomeroff_net_dir, "./data/examples/accuracy_test_data.json"),
    texts, image_paths,
    images, images_bboxs,
    images_points, images_zones,
    region_ids, region_names,
    count_lines, confidences,
    matplotlib_show=False)
# Out:
# + NAME:25.jpeg TRUE:AM5696CK PREDICTED:['AM5696CK']
# [INFO] images_bboxs [[147.0, 1533.0, 511.0, 1733.0, 0.9318088, 0, array([[     146.31,      1653.3],
#        [     182.88,      1530.8],
#        [     515.07,        1600],
#        [     474.33,      1734.9]], dtype=float32)]]
# [INFO] image_points [array([[     146.31,      1653.3],
#        [     182.88,      1530.8],
#        [     515.07,        1600],
#        [     474.33,      1734.9]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:18.jpeg TRUE:AC4921CB PREDICTED:['AC4921CB']
# [INFO] images_bboxs [[869.0, 459.0, 1088.0, 575.0, 0.93413043, 0, array([[     870.97,         575],
#        [     868.22,      508.62],
#        [     1086.4,      460.51],
#        [     1087.2,      519.91]], dtype=float32)]]
# [INFO] image_points [array([[     870.97,         575],
#        [     868.22,      508.62],
#        [     1086.4,      460.51],
#        [     1087.2,      519.91]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:20.jpeg TRUE:BC7007AK PREDICTED:['BC7007AK']
# [INFO] images_bboxs [[744.0, 2157.0, 1009.0, 2291.0, 0.9096747, 0, array([[     742.36,      2238.3],
#        [     768.69,      2157.5],
#        [     1007.6,      2198.9],
#        [     980.57,      2290.7]], dtype=float32)]]
# [INFO] image_points [array([[     742.36,      2238.3],
#        [     768.69,      2157.5],
#        [     1007.6,      2198.9],
#        [     980.57,      2290.7]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:22.jpeg TRUE:AX2756EK PREDICTED:['AX2756EK']
# [INFO] images_bboxs [[354.0, 1144.0, 1059.0, 1380.0, 0.9325046, 0, array([[      350.7,      1380.6],
#        [     390.28,      1184.3],
#        [     1062.8,      1145.8],
#        [     1020.5,      1342.7]], dtype=float32)]]
# [INFO] image_points [array([[      350.7,      1380.6],
#        [     390.28,      1184.3],
#        [     1062.8,      1145.8],
#        [     1020.5,      1342.7]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:2.jpeg TRUE:AT1515CK PREDICTED:['AT1515CK', 'RP69881']
# [INFO] images_bboxs [[2790.0, 1409.0, 3212.0, 1749.0, 0.9396409, 0, array([[       2793,      1747.4],
#        [     2798.8,      1575.1],
#        [     3211.7,      1410.7],
#        [     3196.2,      1570.9]], dtype=float32)], [2455.0, 532.0, 2562.0, 559.0, 0.66932577, 0, array([[     2455.7,      558.77],
#        [       2456,      533.98],
#        [     2559.2,      532.59],
#        [     2559.5,      557.58]], dtype=float32)]]
# [INFO] image_points [array([[       2793,      1747.4],
#        [     2798.8,      1575.1],
#        [     3211.7,      1410.7],
#        [     3196.2,      1570.9]], dtype=float32), array([[     2455.7,      558.77],
#        [       2456,      533.98],
#        [     2559.2,      532.59],
#        [     2559.5,      557.58]], dtype=float32)]
# [INFO] image_region_ids [1, 4]
# [INFO] image_region_names ['eu_ua_2015', 'eu']
# [INFO] image_count_lines [1, 1]
# [INFO] image_confidences [[1.0, 1.0], [1.0, 1.0]]
# + NAME:8.jpeg TRUE:AE1077CO PREDICTED:['AE1077CO']
# [INFO] images_bboxs [[1063.0, 873.0, 1417.0, 980.0, 0.93920666, 0, array([[     1062.8,      979.12],
#        [     1064.8,      895.07],
#        [     1417.3,      872.66],
#        [     1411.2,       950.1]], dtype=float32)]]
# [INFO] image_points [array([[     1062.8,      979.12],
#        [     1064.8,      895.07],
#        [     1417.3,      872.66],
#        [     1411.2,       950.1]], dtype=float32)]
# [INFO] image_region_ids [2]
# [INFO] image_region_names ['eu_ua_2004']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:9.jpeg TRUE:AB3391AK PREDICTED:['AB3391AK']
# [INFO] images_bboxs [[966.0, 783.0, 1158.0, 858.0, 0.9323084, 0, array([[     968.38,      857.93],
#        [     967.24,      813.91],
#        [     1157.3,      782.17],
#        [     1156.8,      824.52]], dtype=float32)]]
# [INFO] image_points [array([[     968.38,      857.93],
#        [     967.24,      813.91],
#        [     1157.3,      782.17],
#        [     1156.8,      824.52]], dtype=float32)]
# [INFO] image_region_ids [2]
# [INFO] image_region_names ['eu_ua_2004']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:1.jpeg TRUE:AT6883CM PREDICTED:['AT6883CM']
# [INFO] images_bboxs [[45.0, 480.0, 92.0, 569.0, 0.8957649, 0, array([[     46.393,      516.49],
#        [     44.642,      481.23],
#        [     90.283,      526.51],
#        [     91.915,      568.66]], dtype=float32)]]
# [INFO] image_points [array([[     46.393,      516.49],
#        [     44.642,      481.23],
#        [     90.283,      526.51],
#        [     91.915,      568.66]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[0.9999974966049194, 1.0]]
# + NAME:4.jpeg TRUE:AC4249CB PREDICTED:['AC4249CB']
# [INFO] images_bboxs [[1117.0, 829.0, 1341.0, 899.0, 0.92681354, 0, array([[       1118,      899.06],
#        [     1118.4,      842.48],
#        [     1339.6,      829.05],
#        [     1338.7,      883.45]], dtype=float32)]]
# [INFO] image_points [array([[       1118,      899.06],
#        [     1118.4,      842.48],
#        [     1339.6,      829.05],
#        [     1338.7,      883.45]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:3.jpeg TRUE:BX0578CE PREDICTED:['BX0578CE']
# [INFO] images_bboxs [[911.0, 592.0, 996.0, 664.0, 0.93242186, 0, array([[     911.48,      664.52],
#        [     910.45,      629.54],
#        [     996.08,      591.78],
#        [     996.04,       623.4]], dtype=float32)]]
# [INFO] image_points [array([[     911.48,      664.52],
#        [     910.45,      629.54],
#        [     996.08,      591.78],
#        [     996.04,       623.4]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:11.jpeg TRUE:BE7425CB PREDICTED:['BE7425CB']
# [INFO] images_bboxs [[1130.0, 292.0, 1212.0, 379.0, 0.92275727, 0, array([[     1140.8,      378.88],
#        [     1129.9,       327.4],
#        [     1202.1,      292.17],
#        [     1211.7,      336.19]], dtype=float32)]]
# [INFO] image_points [array([[     1140.8,      378.88],
#        [     1129.9,       327.4],
#        [     1202.1,      292.17],
#        [     1211.7,      336.19]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:24.jpeg TRUE:AM5696CK PREDICTED:['AM5696CK']
# [INFO] images_bboxs [[255.0, 1471.0, 469.0, 1646.0, 0.9038149, 0, array([[     255.62,      1586.6],
#        [     265.11,      1472.4],
#        [      470.1,      1515.6],
#        [     457.57,      1646.7]], dtype=float32)]]
# [INFO] image_points [array([[     255.62,      1586.6],
#        [     265.11,      1472.4],
#        [      470.1,      1515.6],
#        [     457.57,      1646.7]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:16.jpeg TRUE:AB7333BH PREDICTED:['AB7333BH']
# [INFO] images_bboxs [[1707.0, 855.0, 1852.0, 971.0, 0.9246003, 0, array([[     1710.1,      970.98],
#        [     1709.2,      897.21],
#        [     1850.5,      855.44],
#        [     1850.8,      919.73]], dtype=float32)]]
# [INFO] image_points [array([[     1710.1,      970.98],
#        [     1709.2,      897.21],
#        [     1850.5,      855.44],
#        [     1850.8,      919.73]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:15.jpeg TRUE:AI1382HB PREDICTED:['AI1382HB']
# [INFO] images_bboxs [[625.0, 956.0, 734.0, 1022.0, 0.8924389, 0, array([[     626.52,      993.98],
#        [     626.85,      956.03],
#        [     733.72,      979.93],
#        [     733.08,      1020.8]], dtype=float32)]]
# [INFO] image_points [array([[     626.52,      993.98],
#        [     626.85,      956.03],
#        [     733.72,      979.93],
#        [     733.08,      1020.8]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:21.jpeg TRUE:AB5649CI PREDICTED:['AB5649CI']
# [INFO] images_bboxs [[887.0, 1945.0, 1189.0, 2233.0, 0.93674034, 0, array([[     888.91,        2076],
#        [     903.02,      1945.5],
#        [     1190.1,      2077.5],
#        [     1172.3,      2231.7]], dtype=float32)]]
# [INFO] image_points [array([[     888.91,        2076],
#        [     903.02,      1945.5],
#        [     1190.1,      2077.5],
#        [     1172.3,      2231.7]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:7.jpeg TRUE:AO1306CH PREDICTED:['AO1306CH']
# [INFO] images_bboxs [[105.0, 668.0, 375.0, 801.0, 0.93720144, 0, array([[     115.91,      732.04],
#        [     104.67,      670.15],
#        [     364.96,       735.5],
#        [     373.81,      801.63]], dtype=float32)]]
# [INFO] image_points [array([[     115.91,      732.04],
#        [     104.67,      670.15],
#        [     364.96,       735.5],
#        [     373.81,      801.63]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:13.jpeg TRUE:AB0680EA PREDICTED:['AB0680EA']
# [INFO] images_bboxs [[132.0, 392.0, 275.0, 464.0, 0.9330289, 0, array([[     138.32,      423.48],
#        [      132.4,      391.36],
#        [      271.2,      429.04],
#        [      275.4,      464.66]], dtype=float32)]]
# [INFO] image_points [array([[     138.32,      423.48],
#        [      132.4,      391.36],
#        [      271.2,      429.04],
#        [      275.4,      464.66]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:6.jpeg TRUE:BC3496HC PREDICTED:['BC3496HC']
# [INFO] images_bboxs [[3329.0, 1522.0, 3651.0, 1827.0, 0.9286022, 0, array([[     3354.4,      1823.7],
#        [     3329.7,      1656.7],
#        [     3633.2,        1524],
#        [     3653.2,      1662.1]], dtype=float32)]]
# [INFO] image_points [array([[     3354.4,      1823.7],
#        [     3329.7,      1656.7],
#        [     3633.2,        1524],
#        [     3653.2,      1662.1]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:5.jpeg TRUE:BC3496HC PREDICTED:['BC3496HC']
# [INFO] images_bboxs [[612.0, 1544.0, 902.0, 1751.0, 0.9389937, 0, array([[     609.35,      1656.9],
#        [     630.19,      1542.4],
#        [     901.65,      1618.2],
#        [     877.95,      1751.1]], dtype=float32)]]
# [INFO] image_points [array([[     609.35,      1656.9],
#        [     630.19,      1542.4],
#        [     901.65,      1618.2],
#        [     877.95,      1751.1]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:17.jpeg TRUE:AB7642CT PREDICTED:['AB7642CT']
# [INFO] images_bboxs [[638.0, 909.0, 801.0, 952.0, 0.91905135, 0, array([[      637.4,      952.87],
#        [     638.41,      915.94],
#        [     800.17,      909.13],
#        [     799.41,      944.86]], dtype=float32)]]
# [INFO] image_points [array([[      637.4,      952.87],
#        [     638.41,      915.94],
#        [     800.17,      909.13],
#        [     799.41,      944.86]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:14.jpeg TRUE:BM1930BM PREDICTED:['BM1930BM']
# [INFO] images_bboxs [[165.0, 771.0, 423.0, 847.0, 0.9106453, 0, array([[     171.59,      829.67],
#        [     166.11,      770.57],
#        [     420.18,      788.59],
#        [     423.59,      847.73]], dtype=float32)]]
# [INFO] image_points [array([[     171.59,      829.67],
#        [     166.11,      770.57],
#        [     420.18,      788.59],
#        [     423.59,      847.73]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:19.jpeg TRUE:BC9911BK PREDICTED:['BC9911BK']
# [INFO] images_bboxs [[1537.0, 1337.0, 2410.0, 1554.0, 0.91503567, 0, array([[     1542.3,      1535.5],
#        [     1541.8,      1336.4],
#        [       2410,      1354.4],
#        [     2405.3,        1555]], dtype=float32)]]
# [INFO] image_points [array([[     1542.3,      1535.5],
#        [     1541.8,      1336.4],
#        [       2410,      1354.4],
#        [     2405.3,        1555]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:10.jpeg TRUE:BE7425CB PREDICTED:['BE7425CB']
# [INFO] images_bboxs [[1051.0, 481.0, 1156.0, 575.0, 0.9293575, 0, array([[       1050,      575.29],
#        [     1054.3,      520.58],
#        [     1156.2,      480.57],
#        [     1151.4,      527.66]], dtype=float32)]]
# [INFO] image_points [array([[       1050,      575.29],
#        [     1054.3,      520.58],
#        [     1156.2,      480.57],
#        [     1151.4,      527.66]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:23.jpeg TRUE:AA7564MX PREDICTED:['AA7564MX']
# [INFO] images_bboxs [[138.0, 929.0, 304.0, 1059.0, 0.9250175, 0, array([[     139.37,         996],
#        [     140.45,      930.18],
#        [     305.19,      982.55],
#        [     302.05,      1059.1]], dtype=float32)]]
# [INFO] image_points [array([[     139.37,         996],
#        [     140.45,      930.18],
#        [     305.19,      982.55],
#        [     302.05,      1059.1]], dtype=float32)]
# [INFO] image_region_ids [2]
# [INFO] image_region_names ['eu_ua_2004']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:12.jpeg TRUE:AB0680EA PREDICTED:['AB0680EA']
# [INFO] images_bboxs [[52.0, 339.0, 124.0, 411.0, 0.9308898, 0, array([[     56.099,      364.67],
#        [     51.362,      338.82],
#        [     119.11,      380.42],
#        [      123.8,      410.48]], dtype=float32)]]
# [INFO] image_points [array([[     56.099,      364.67],
#        [     51.362,      338.82],
#        [     119.11,      380.42],
#        [      123.8,      410.48]], dtype=float32)]
# [INFO] image_region_ids [1]
# [INFO] image_region_names ['eu_ua_2015']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[0.9999229907989502, 1.0]]
# TOTAL GOOD: 1.0
# TOTAL BAD: 0.0

# %% [markdown]
# # Multiline numberplate

# %%
image_paths = glob(os.path.join(nomeroff_net_dir, "./data/examples/benchmark_multiline_np_images/*"))
result = number_plate_detection_and_reading(image_paths, quality_profile=[3, 1, 0])
# Out:
# 	Tile 1/1
# 	Tile 1/1

# %%
(images, images_bboxs, 
 images_points, images_zones, region_ids, 
 region_names, count_lines, 
 confidences, texts) = unzip(result)

# %%
number_plate_detection_and_reading.text_accuracy_test_from_file(
    os.path.join(nomeroff_net_dir, "./data/examples/accuracy_test_data_multiline.json"),
    texts, image_paths,
    images, images_bboxs,
    images_points, images_zones,
    region_ids, region_names,
    count_lines, confidences,
    matplotlib_show=False)
# Out:
# + NAME:26.jpeg TRUE:10922BX PREDICTED:['10922BX']
# [INFO] images_bboxs [[973.0, 496.0, 1486.0, 936.0, 0.89658415, 0, array([[     1012.4,      954.34],
#        [     970.69,      548.33],
#        [     1438.7,      480.86],
#        [     1476.3,      854.15]], dtype=float32)]]
# [INFO] image_points [array([[     1012.4,      954.34],
#        [     970.69,      548.33],
#        [     1438.7,      480.86],
#        [     1476.3,      854.15]], dtype=float32)]
# [INFO] image_region_ids [12]
# [INFO] image_region_names ['su']
# [INFO] image_count_lines [2]
# [INFO] image_confidences [[1.0, 1.0]]
# - NAME:29.jpeg TRUE:7686ЖЦ PREDICTED:['88']
# [INFO] images_bboxs [[636.0, 518.0, 744.0, 642.0, 0.9415238, 0, array([[     637.32,      532.37],
#        [     739.91,       517.3],
#        [     742.19,      623.67],
#        [      642.7,      642.71]], dtype=float32)]]
# [INFO] image_points [array([[     637.32,      532.37],
#        [     739.91,       517.3],
#        [     742.19,      623.67],
#        [      642.7,      642.71]], dtype=float32)]
# [INFO] image_region_ids [4]
# [INFO] image_region_names ['eu']
# [INFO] image_count_lines [1]
# [INFO] image_confidences [[0.9916239380836487, 0.9858183264732361]]
# + NAME:30.jpeg TRUE:6808XO PREDICTED:['6808XO', 'AIA0IT']
# [INFO] images_bboxs [[673.0, 366.0, 773.0, 485.0, 0.9274554, 0, array([[      679.2,       485.2],
#        [     673.32,      389.38],
#        [     769.18,      365.64],
#        [     772.35,      453.48]], dtype=float32)], [177.0, 218.0, 230.0, 246.0, 0.6977388, 0, array([[     181.17,      245.97],
#        [     177.86,      219.16],
#        [     227.68,      217.99],
#        [     230.54,      244.37]], dtype=float32)]]
# [INFO] image_points [array([[      679.2,       485.2],
#        [     673.32,      389.38],
#        [     769.18,      365.64],
#        [     772.35,      453.48]], dtype=float32), array([[     181.17,      245.97],
#        [     177.86,      219.16],
#        [     227.68,      217.99],
#        [     230.54,      244.37]], dtype=float32)]
# [INFO] image_region_ids [12, 2]
# [INFO] image_region_names ['su', 'eu_ua_2004']
# [INFO] image_count_lines [2, 1]
# [INFO] image_confidences [[1.0, 1.0], [1.0, 0.9937292337417603]]
# + NAME:28.jpeg TRUE:30217BI PREDICTED:['30217BI']
# [INFO] images_bboxs [[205.0, 338.0, 342.0, 431.0, 0.934733, 0, array([[     206.42,      430.53],
#        [     206.78,      341.39],
#        [     340.81,      337.49],
#        [     339.68,      427.56]], dtype=float32)]]
# [INFO] image_points [array([[     206.42,      430.53],
#        [     206.78,      341.39],
#        [     340.81,      337.49],
#        [     339.68,      427.56]], dtype=float32)]
# [INFO] image_region_ids [12]
# [INFO] image_region_names ['su']
# [INFO] image_count_lines [2]
# [INFO] image_confidences [[1.0, 1.0]]
# + NAME:27.jpeg TRUE:41353AE PREDICTED:['41353AE']
# [INFO] images_bboxs [[779.0, 321.0, 1161.0, 602.0, 0.93448603, 0, array([[     781.17,      578.07],
#        [     786.95,      319.26],
#        [     1148.8,      343.24],
#        [       1144,      601.65]], dtype=float32)]]
# [INFO] image_points [array([[     781.17,      578.07],
#        [     786.95,      319.26],
#        [     1148.8,      343.24],
#        [       1144,      601.65]], dtype=float32)]
# [INFO] image_region_ids [12]
# [INFO] image_region_names ['su']
# [INFO] image_count_lines [2]
# [INFO] image_confidences [[1.0, 1.0]]
# TOTAL GOOD: 0.8
# TOTAL BAD: 0.2
