# %% [markdown]
# # This example demonstrate how to train region classification (standart image classification model).

# %% [markdown]
# For train datasets please download last version of dataset [https://nomeroff.net.ua/datasets/](https://nomeroff.net.ua/datasets/). Unpack archive and rename to **./datasets/** .
# For examle
# ```bash
# cd ./datasets
# wget https://nomeroff.net.ua/datasets/autoriaNumberplateOptions3Dataset-2021-03-05.zip
# unzip autoriaNumberplateOptions3Dataset-2021-03-05.zip
# mv autoriaNumberplateOptions3Dataset-2021-03-05 options
# ```
# or use your own dataset.

# %%
# Specify device
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0" 
# os.environ["CUDA_VISIBLE_DEVICES"] = ""  # For CPU inference
os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"

# %%
import os
import sys
import warnings
warnings.filterwarnings('ignore')

# change this property
NOMEROFF_NET_DIR = os.path.abspath('../')

DATASET_NAME = "options"
VERSION = "2021_05_22_uacustom"

LOG_DIR = os.path.join(NOMEROFF_NET_DIR, "logs/")
PATH_TO_DATASET = os.path.join(NOMEROFF_NET_DIR, "datasets/", DATASET_NAME)
PATH_TO_TMP_CUSTOM_DATASET = os.path.join(NOMEROFF_NET_DIR, "datasets/", f"{DATASET_NAME}_custom")
RESULT_PATH = os.path.join(NOMEROFF_NET_DIR, "models/", 'numberplate_{}_{}.h5'.format(DATASET_NAME, VERSION))

sys.path.append(NOMEROFF_NET_DIR)

from NomeroffNet import OptionsDetector
from NomeroffNet.tools import custom_options

# %% [markdown]
# ### Prepare custom data

# %%
class_region_custom = [
            "xx-unknown",
            "eu-ua-2015",
            "eu-ua-2004",
            "eu-ua-1995",
            "eu",
            "xx-transit",
            "ru",
            "eu-ua-ordlo-dpr",
            "eu-ua-ordlo-lpr",
            "su"
        ]

customOptionsMaker = custom_options.CustomOptionsMaker(
    PATH_TO_DATASET,
    PATH_TO_TMP_CUSTOM_DATASET, 
    OptionsDetector.get_class_region_all(),
    class_region_custom
)
customOptionsMaker.make()
# Out:
# dir: /var/www/nomeroff-net21/datasets/options option_dir train custom_options_sub_dirs[0] ann
# us2VEbYdzaXxjeliWKIRCf95S7TgJm8PB3A4tLrvONknMDyqoQ eu -> custom_region_id 4 -> 4
# 260595195 eu-ua-2004 -> custom_region_id 2 -> 2
# 261405716 eu-ua-1995 -> custom_region_id 3 -> 3
# 53442_Ч2695ТЮ_0_1 su -> custom_region_id 12 -> 9
# 260035138 xx-unknown -> custom_region_id 0 -> 0
# 261254196 xx-unknown -> custom_region_id 0 -> 0
# 260223306 xx-unknown -> custom_region_id 0 -> 0
# option_zero246081063-0 xx-unknown -> custom_region_id 0 -> 0
# 260245002 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248374011-0 xx-unknown -> custom_region_id 0 -> 0
# 260262156 xx-unknown -> custom_region_id 0 -> 0
# 259998427 eu-ua-2004 -> custom_region_id 2 -> 2
# 260233021 xx-transit -> custom_region_id 5 -> 5
# 19351_З6599ДП_0_1 su -> custom_region_id 12 -> 9
# 261472407 eu-ua-1995 -> custom_region_id 3 -> 3
# 260046654 eu-ua-2004 -> custom_region_id 2 -> 2
# 260045469 eu-ua-1995 -> custom_region_id 3 -> 3
# 261197324 xx-transit -> custom_region_id 5 -> 5
# X833PX54_0 ru -> custom_region_id 6 -> 6
# T689AP197_0 ru -> custom_region_id 6 -> 6
# 260019545 eu-ua-2015 -> custom_region_id 1 -> 1
# 259995580 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero245068393-0 xx-unknown -> custom_region_id 0 -> 0
# option_zero247668486-0 xx-unknown -> custom_region_id 0 -> 0
# 260254701 xx-unknown -> custom_region_id 0 -> 0
# 260226910 eu-ua-2015 -> custom_region_id 1 -> 1
# 261238249 eu-ua-1995 -> custom_region_id 3 -> 3
# 260796669 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2004_233850182_BH9778II eu-ua-2004 -> custom_region_id 2 -> 2
# 260224514 xx-unknown -> custom_region_id 0 -> 0
# 46038_В6998ДН_1_1 su -> custom_region_id 12 -> 9
# Y001TB61_0 ru -> custom_region_id 6 -> 6
# 260555022 eu-ua-2004 -> custom_region_id 2 -> 2
# 5179-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# eu-ua-2015_381372900_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260223479 xx-unknown -> custom_region_id 0 -> 0
# 259983499 eu-ua-2015 -> custom_region_id 1 -> 1
# 46344_З0093ПЕ_0_1 su -> custom_region_id 12 -> 9
# 260004862 eu-ua-2015 -> custom_region_id 1 -> 1
# 259960614 eu-ua-1995 -> custom_region_id 3 -> 3
# 260572621 eu-ua-2004 -> custom_region_id 2 -> 2
# 259967181 eu -> custom_region_id 4 -> 4
# 260236228 xx-unknown -> custom_region_id 0 -> 0
# 260074099 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero246187861-0 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_380677987_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260222216 xx-unknown -> custom_region_id 0 -> 0
# 259727003 xx-transit -> custom_region_id 5 -> 5
# 260595660 eu-ua-2015 -> custom_region_id 1 -> 1
# P800XX64_0 ru -> custom_region_id 6 -> 6
# 260233617 xx-unknown -> custom_region_id 0 -> 0
# 261441769 xx-transit -> custom_region_id 5 -> 5
# B538TH74_0 ru -> custom_region_id 6 -> 6
# 95084_Б2688БР_1_1 su -> custom_region_id 12 -> 9
# 260016876 eu-ua-2004 -> custom_region_id 2 -> 2
# 20328_П6483ГО_0_1 su -> custom_region_id 12 -> 9
# 260234188 eu-ua-2004 -> custom_region_id 2 -> 2
# 260561716 eu-ua-2004 -> custom_region_id 2 -> 2
# 259969132 eu-ua-2015 -> custom_region_id 1 -> 1
# 261042190 xx-transit -> custom_region_id 5 -> 5
# Rxvw0qnaSsolbhgtueWOB7LFUG8c3NDp612zfTQmCP5E9rKYiZ eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# P742TH98_0 ru -> custom_region_id 6 -> 6
# 17440_Т9189ВВ_0_1 su -> custom_region_id 12 -> 9
# 260561510 eu-ua-1995 -> custom_region_id 3 -> 3
# 260053019 eu-ua-1995 -> custom_region_id 3 -> 3
# 261428384 xx-transit -> custom_region_id 5 -> 5
# 260105916 eu -> custom_region_id 4 -> 4
# 260048080 eu-ua-2015 -> custom_region_id 1 -> 1
# O010MT177_0 ru -> custom_region_id 6 -> 6
# Y393HO52_0 ru -> custom_region_id 6 -> 6
# 260232153 eu-ua-2015 -> custom_region_id 1 -> 1
# 260586810 xx-unknown -> custom_region_id 0 -> 0
# 260257676 eu-ua-2004 -> custom_region_id 2 -> 2
# 260243592 eu-ua-2015 -> custom_region_id 1 -> 1
# 261067914 eu-ua-1995 -> custom_region_id 3 -> 3
# 260068175 xx-unknown -> custom_region_id 0 -> 0
# 259977369 eu -> custom_region_id 4 -> 4
# option_zero248279167-0 xx-unknown -> custom_region_id 0 -> 0
# 59910_Е5624ВТ_2_1 su -> custom_region_id 12 -> 9
# option_zero247749286-0 xx-unknown -> custom_region_id 0 -> 0
# 260240076 eu-ua-2004 -> custom_region_id 2 -> 2
# 261387101 xx-unknown -> custom_region_id 0 -> 0
# 260244107 eu-ua-2004 -> custom_region_id 2 -> 2
# 260017515 eu-ua-1995 -> custom_region_id 3 -> 3
# su_313190531_0 su -> custom_region_id 12 -> 9
# 259977196 eu-ua-2004 -> custom_region_id 2 -> 2
# 260252862 xx-unknown -> custom_region_id 0 -> 0
# 260016410 eu-ua-2004 -> custom_region_id 2 -> 2
# 3_eu_ua_2004_235202042_AA8AE eu-ua-2004 -> custom_region_id 2 -> 2
# 260553723 eu-ua-2004 -> custom_region_id 2 -> 2
# 13366_Р4006ХА_0_1 su -> custom_region_id 12 -> 9
# E7360XM su -> custom_region_id 12 -> 9
# 260247306 eu-ua-2015 -> custom_region_id 1 -> 1
# 260000440 eu-ua-2004 -> custom_region_id 2 -> 2
# 260783058 eu-ua-1995 -> custom_region_id 3 -> 3
# TEmSvDIlHpihFYa65JqOwdNWVKt0r97XbLZ8UCGfokcjRPyQsx eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 14469_В0154ВН_0_1 su -> custom_region_id 12 -> 9
# 260701244 xx-unknown -> custom_region_id 0 -> 0
# 260046591 xx-transit -> custom_region_id 5 -> 5
# 259984006 eu-ua-2015 -> custom_region_id 1 -> 1
# 259969220 eu -> custom_region_id 4 -> 4
# B480XO98_0 ru -> custom_region_id 6 -> 6
# su_289149774_0 su -> custom_region_id 12 -> 9
# 260108856 eu -> custom_region_id 4 -> 4
# 261180901 xx-transit -> custom_region_id 5 -> 5
# 87771_Д5670ДН_0_1 su -> custom_region_id 12 -> 9
# 8314_В3108ХА_0_1 su -> custom_region_id 12 -> 9
# 260080311 eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2015_326977526_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260075349 eu-ua-2015 -> custom_region_id 1 -> 1
# 260599842 eu -> custom_region_id 4 -> 4
# 259955336 eu-ua-2015 -> custom_region_id 1 -> 1
# 8117_Г5278ХА_0_1 su -> custom_region_id 12 -> 9
# 259981315 eu -> custom_region_id 4 -> 4
# option_zero248501683-0 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2015_266385552_BH1787IE eu-ua-2015 -> custom_region_id 1 -> 1
# 260224407 eu-ua-1995 -> custom_region_id 3 -> 3
# 260230111 xx-unknown -> custom_region_id 0 -> 0
# 259936345 xx-unknown -> custom_region_id 0 -> 0
# 260223352 xx-unknown -> custom_region_id 0 -> 0
# 260579171 eu -> custom_region_id 4 -> 4
# 3MNXLIKE8ojOPdcrzymqutJ6ZhSwlCv7D9BVAWFn5gbTfHYax0 eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 260238761 xx-unknown -> custom_region_id 0 -> 0
# 260015613 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero245006142-0 xx-unknown -> custom_region_id 0 -> 0
# 260570610 eu -> custom_region_id 4 -> 4
# X214XX64_1 ru -> custom_region_id 6 -> 6
# 260167687 xx-unknown -> custom_region_id 0 -> 0
# 260121339 eu -> custom_region_id 4 -> 4
# 260003103 eu-ua-2004 -> custom_region_id 2 -> 2
# M002MK199_0 ru -> custom_region_id 6 -> 6
# 260027836 eu-ua-2004 -> custom_region_id 2 -> 2
# 260029542 xx-unknown -> custom_region_id 0 -> 0
# 259956178 eu -> custom_region_id 4 -> 4
# 260013859 eu-ua-2004 -> custom_region_id 2 -> 2
# 261358882 xx-unknown -> custom_region_id 0 -> 0
# M523MP31_0 ru -> custom_region_id 6 -> 6
# 89214X su -> custom_region_id 12 -> 9
# 260245967 eu-ua-2015 -> custom_region_id 1 -> 1
# 261266512 xx-transit -> custom_region_id 5 -> 5
# 260563959 eu-ua-2004 -> custom_region_id 2 -> 2
# fV72vipMWYjUsJzko4r8cZSD19HqReEgywhLuItdPQA0nxKbmC eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260250292 xx-unknown -> custom_region_id 0 -> 0
# 260038156 eu-ua-2015 -> custom_region_id 1 -> 1
# 259979427 xx-unknown -> custom_region_id 0 -> 0
# 259963964 eu-ua-2015 -> custom_region_id 1 -> 1
# 18697_Т3916ХА_0_1 su -> custom_region_id 12 -> 9
# M821MM98_0 ru -> custom_region_id 6 -> 6
# eu-ua-2015_325365553_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260031483 xx-unknown -> custom_region_id 0 -> 0
# 260233578 xx-unknown -> custom_region_id 0 -> 0
# option_zero247667555-0 xx-unknown -> custom_region_id 0 -> 0
# 260994858 eu-ua-1995 -> custom_region_id 3 -> 3
# 260229234 eu -> custom_region_id 4 -> 4
# 140540_Е0741МБ_2_1 su -> custom_region_id 12 -> 9
# 260256360 eu-ua-2004 -> custom_region_id 2 -> 2
# 260228920 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2015_246323683_BH070AC eu-ua-2015 -> custom_region_id 1 -> 1
# 260555324 eu-ua-1995 -> custom_region_id 3 -> 3
# 260868972 eu-ua-1995 -> custom_region_id 3 -> 3
# 10127_М5561РО_0_1 su -> custom_region_id 12 -> 9
# 260254509 eu-ua-2015 -> custom_region_id 1 -> 1
# 260086750 eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2015_379808165_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260082617 eu-ua-2015 -> custom_region_id 1 -> 1
# 60890_Ч0715СА_0_1 su -> custom_region_id 12 -> 9
# Y828HT199_0 ru -> custom_region_id 6 -> 6
# Y399XT54_0 ru -> custom_region_id 6 -> 6
# 3_eu_ua_2015_349971991_ATI17AE eu-ua-2015 -> custom_region_id 1 -> 1
# 260065293 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248997337-0 xx-unknown -> custom_region_id 0 -> 0
# 260251643 eu-ua-1995 -> custom_region_id 3 -> 3
# 260037808 eu -> custom_region_id 4 -> 4
# 259938403 eu -> custom_region_id 4 -> 4
# 260234589 eu-ua-1995 -> custom_region_id 3 -> 3
# 260246948 xx-unknown -> custom_region_id 0 -> 0
# 259968570 eu-ua-2015 -> custom_region_id 1 -> 1
# 259970743 eu-ua-2004 -> custom_region_id 2 -> 2
# 260175323 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2015_322473076_BH8871IK eu-ua-2015 -> custom_region_id 1 -> 1
# 260905657 xx-transit -> custom_region_id 5 -> 5
# 260254799 xx-unknown -> custom_region_id 0 -> 0
# 259987218 xx-unknown -> custom_region_id 0 -> 0
# 22235_Т4623ДП_0_1 su -> custom_region_id 12 -> 9
# 91301_А0274ХІ_0_1 su -> custom_region_id 12 -> 9
# 261256079 eu-ua-1995 -> custom_region_id 3 -> 3
# 3_eu_ua_2015_283877945_AXE1IB eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2015_379984172_0 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248281750-0 xx-unknown -> custom_region_id 0 -> 0
# 260242265 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero245008927-0 xx-unknown -> custom_region_id 0 -> 0
# 260225902 eu-ua-2015 -> custom_region_id 1 -> 1
# B353BK35_0 ru -> custom_region_id 6 -> 6
# B681OX116_0 ru -> custom_region_id 6 -> 6
# 260174281 xx-transit -> custom_region_id 5 -> 5
# 260035305 eu -> custom_region_id 4 -> 4
# 260248447 eu-ua-2004 -> custom_region_id 2 -> 2
# 261386795 xx-transit -> custom_region_id 5 -> 5
# 260029058 xx-unknown -> custom_region_id 0 -> 0
# 260063735 eu-ua-2015 -> custom_region_id 1 -> 1
# 260560043 eu-ua-2004 -> custom_region_id 2 -> 2
# 3740-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260246699 eu -> custom_region_id 4 -> 4
# 260712397 eu-ua-2015 -> custom_region_id 1 -> 1
# 261482785 xx-transit -> custom_region_id 5 -> 5
# 260222282 eu-ua-2004 -> custom_region_id 2 -> 2
# 260227163 eu-ua-2004 -> custom_region_id 2 -> 2
# su_322252569_0 su -> custom_region_id 12 -> 9
# 260035535 eu-ua-2015 -> custom_region_id 1 -> 1
# 260230030 xx-unknown -> custom_region_id 0 -> 0
# 46302_Г0635КШ_0_1 su -> custom_region_id 12 -> 9
# 260235326 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2004_197549159_AH18IE eu-ua-2004 -> custom_region_id 2 -> 2
# eu_326960090_0 eu -> custom_region_id 4 -> 4
# 260240690 eu-ua-2015 -> custom_region_id 1 -> 1
# DOe7pvR4HlCFksxjo0X1zMSIBc93uUyGLTN6VmgKA5wYdJZhbQ eu-ua-2015 -> custom_region_id 1 -> 1
# QP2FHYDpBkLR76bJ14NfIrja3vMCgnuV0O9wTyhiXKcdW5EmGt eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 259987474 eu-ua-2004 -> custom_region_id 2 -> 2
# 260246850 xx-unknown -> custom_region_id 0 -> 0
# 260028148 eu-ua-2004 -> custom_region_id 2 -> 2
# 260569743 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2015_194925172_BT13AE eu-ua-2015 -> custom_region_id 1 -> 1
# 259963148 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero246405933-0 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_379820401_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260784705 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero247992048-0 xx-unknown -> custom_region_id 0 -> 0
# option_zero246086925-0 xx-unknown -> custom_region_id 0 -> 0
# 259938007 xx-unknown -> custom_region_id 0 -> 0
# 260233778 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2015_345900577_AT5T7A eu-ua-2015 -> custom_region_id 1 -> 1
# 261209488 eu-ua-1995 -> custom_region_id 3 -> 3
# 260118108 eu-ua-1995 -> custom_region_id 3 -> 3
# 260001513 eu-ua-2015 -> custom_region_id 1 -> 1
# 7928_С5271ХА_0_1 su -> custom_region_id 12 -> 9
# 260073682 eu -> custom_region_id 4 -> 4
# 260228406 xx-unknown -> custom_region_id 0 -> 0
# 260222817 xx-unknown -> custom_region_id 0 -> 0
# M997MM50_0 ru -> custom_region_id 6 -> 6
# 261165837 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero246111097-0 xx-unknown -> custom_region_id 0 -> 0
# rkVdKRi3hJjf0eLzTUDG74PbwXWpnclx5CaI1uHEQqOS6YtmvZ eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 259990492 eu -> custom_region_id 4 -> 4
# O703OO42_0 ru -> custom_region_id 6 -> 6
# 260636898 eu-ua-1995 -> custom_region_id 3 -> 3
# 89481_С3554ХІ_0_1 su -> custom_region_id 12 -> 9
# 3_eu_ua_2004_285031565_BTT18AI eu-ua-2004 -> custom_region_id 2 -> 2
# 260594832 eu -> custom_region_id 4 -> 4
# 260118479 eu-ua-2015 -> custom_region_id 1 -> 1
# Adl4jMzxIpF1DQNscbu97XkYWaKwheLqrRPEJ0BCU8nyVS32Tt eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# su_314364226_0 su -> custom_region_id 12 -> 9
# 260001517 eu-ua-2015 -> custom_region_id 1 -> 1
# 260847913 xx-transit -> custom_region_id 5 -> 5
# 261249442 eu-ua-1995 -> custom_region_id 3 -> 3
# 260090579 eu-ua-1995 -> custom_region_id 3 -> 3
# 260082696 eu-ua-2004 -> custom_region_id 2 -> 2
# 260250161 eu-ua-2015 -> custom_region_id 1 -> 1
# 260582797 eu -> custom_region_id 4 -> 4
# eu-ua-2015_379937567_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260554418 eu-ua-2004 -> custom_region_id 2 -> 2
# su_384060253_0 su -> custom_region_id 12 -> 9
# 260580318 eu -> custom_region_id 4 -> 4
# 10384_Г7727СФ_3_1 su -> custom_region_id 12 -> 9
# option_zero246183843-0 xx-unknown -> custom_region_id 0 -> 0
# 260011475 eu -> custom_region_id 4 -> 4
# 259984337 eu-ua-1995 -> custom_region_id 3 -> 3
# 259937908 xx-unknown -> custom_region_id 0 -> 0
# 260222743 xx-unknown -> custom_region_id 0 -> 0
# 260251008 eu -> custom_region_id 4 -> 4
# 18215_А4805КУ_0_1 su -> custom_region_id 12 -> 9
# 260809324 eu-ua-1995 -> custom_region_id 3 -> 3
# 260583385 eu -> custom_region_id 4 -> 4
# 259941107 xx-unknown -> custom_region_id 0 -> 0
# 260086290 eu-ua-2015 -> custom_region_id 1 -> 1
# 260034052 xx-unknown -> custom_region_id 0 -> 0
# 260243468 xx-unknown -> custom_region_id 0 -> 0
# 260000733 eu -> custom_region_id 4 -> 4
# 39544_О5327ОБ_0_1 su -> custom_region_id 12 -> 9
# 260797915 eu-ua-1995 -> custom_region_id 3 -> 3
# 260264531 xx-unknown -> custom_region_id 0 -> 0
# 3352_Г8855КУ_0_1 su -> custom_region_id 12 -> 9
# eu-ua-2015_380055315_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 10447-main_0 eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 260599980 eu-ua-2004 -> custom_region_id 2 -> 2
# 261162792 xx-transit -> custom_region_id 5 -> 5
# 260258975 xx-unknown -> custom_region_id 0 -> 0
# 260244457 xx-unknown -> custom_region_id 0 -> 0
# 1_su_199113285_9244ІОА su -> custom_region_id 12 -> 9
# 260255593 eu-ua-2004 -> custom_region_id 2 -> 2
# 36062_Г9757ЯР_0_1 su -> custom_region_id 12 -> 9
# option_zero245714588-0 xx-unknown -> custom_region_id 0 -> 0
# 260106475 eu -> custom_region_id 4 -> 4
# option_zero248153030-0 xx-unknown -> custom_region_id 0 -> 0
# 260226516 xx-unknown -> custom_region_id 0 -> 0
# 25083_Л5874МН_0_1 su -> custom_region_id 12 -> 9
# 260052410 eu-ua-2015 -> custom_region_id 1 -> 1
# 259970745 eu -> custom_region_id 4 -> 4
# 260079321 eu-ua-2015 -> custom_region_id 1 -> 1
# 61830_Т8147ДП_0_1 su -> custom_region_id 12 -> 9
# T429OA35_0 ru -> custom_region_id 6 -> 6
# X001XO74_0 ru -> custom_region_id 6 -> 6
# 260037144 eu -> custom_region_id 4 -> 4
# 24826_Ж2676МИ_0_1 su -> custom_region_id 12 -> 9
# 259968619 eu-ua-2015 -> custom_region_id 1 -> 1
# 260250812 eu -> custom_region_id 4 -> 4
# 259998704 eu-ua-2004 -> custom_region_id 2 -> 2
# M050BO31_0 ru -> custom_region_id 6 -> 6
# 260564125 eu-ua-2004 -> custom_region_id 2 -> 2
# eu-ua-2015_337633982_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260119663 eu-ua-2015 -> custom_region_id 1 -> 1
# 30891_Ч3177ХА_1_1 su -> custom_region_id 12 -> 9
# 43094_Л6455ЗП_0_1 su -> custom_region_id 12 -> 9
# 260615414 eu-ua-1995 -> custom_region_id 3 -> 3
# 86390_А8923ХА_1_1 su -> custom_region_id 12 -> 9
# 259942522 xx-unknown -> custom_region_id 0 -> 0
# 259978383 eu-ua-2015 -> custom_region_id 1 -> 1
# 33484_М4126ТЛ_0_1 su -> custom_region_id 12 -> 9
# 11860_Ч4236МТ_0_1 su -> custom_region_id 12 -> 9
# 11341-main_0 eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 260607838 eu-ua-2015 -> custom_region_id 1 -> 1
# 1_su_194141713_А1486ІО su -> custom_region_id 12 -> 9
# P222AB197_0 ru -> custom_region_id 6 -> 6
# M200TT199_0 ru -> custom_region_id 6 -> 6
# 260249679 eu-ua-2015 -> custom_region_id 1 -> 1
# 128083_В0007СІ_0_1 su -> custom_region_id 12 -> 9
# option_zero245722642-0 xx-unknown -> custom_region_id 0 -> 0
# option_zero248041838-0 xx-unknown -> custom_region_id 0 -> 0
# 260097567 eu-ua-1995 -> custom_region_id 3 -> 3
# 260189096 eu-ua-1995 -> custom_region_id 3 -> 3
# 260098881 eu -> custom_region_id 4 -> 4
# wPdbvBQeI2UFtacqxL4HgrA6GuOWkXnzMlmfhCTRSZ3JoDYV09 eu-ua-2015 -> custom_region_id 1 -> 1
# 260040878 eu-ua-2004 -> custom_region_id 2 -> 2
# 260564411 eu-ua-2004 -> custom_region_id 2 -> 2
# 260253120 eu-ua-2015 -> custom_region_id 1 -> 1
# 261198421 xx-unknown -> custom_region_id 0 -> 0
# 45861_В1191ХА_0_1 su -> custom_region_id 12 -> 9
# 260262138 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_380813931_0 eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2004_327248421_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260258402 eu-ua-2015 -> custom_region_id 1 -> 1
# 260235422 eu -> custom_region_id 4 -> 4
# 12088_Г3390ХА_0_1 su -> custom_region_id 12 -> 9
# su_312470040_0 su -> custom_region_id 12 -> 9
# 259989724 eu -> custom_region_id 4 -> 4
# 261454488 eu-ua-1995 -> custom_region_id 3 -> 3
# 260055098 eu -> custom_region_id 4 -> 4
# eu-ua-2004_381717129_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260620041 xx-unknown -> custom_region_id 0 -> 0
# 260963768 eu-ua-1995 -> custom_region_id 3 -> 3
# 261042642 xx-transit -> custom_region_id 5 -> 5
# 260678015 eu-ua-1995 -> custom_region_id 3 -> 3
# eu-ua-2015_323742362_0 eu-ua-2015 -> custom_region_id 1 -> 1
# X482TT52_0 ru -> custom_region_id 6 -> 6
# 260071160 eu-ua-2015 -> custom_region_id 1 -> 1
# 260247301 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero245862439-0 xx-unknown -> custom_region_id 0 -> 0
# 260261227 eu-ua-2004 -> custom_region_id 2 -> 2
# eu-ua-2015_380912444_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260031272 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_379972400_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 4288-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# bUsF5ka8fZWvAMzLwQDYrXEu12mRgd0i9q3JjPITh4BtxyGcH6 eu-ua-2004 -> custom_region_id 2 -> 2
# M091MY68_0 ru -> custom_region_id 6 -> 6
# 35313_Д1012ВИ_0_1 su -> custom_region_id 12 -> 9
# 260250772 xx-unknown -> custom_region_id 0 -> 0
# option_zero245709158-0 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2004_326534215_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 38020_Ц4654КЕ_0_1 su -> custom_region_id 12 -> 9
# option_zero237851380-0 xx-unknown -> custom_region_id 0 -> 0
# 260087039 eu-ua-1995 -> custom_region_id 3 -> 3
# 128170_Е2647РЯ_0_1 su -> custom_region_id 12 -> 9
# K756CC46_0 ru -> custom_region_id 6 -> 6
# 260835769 eu-ua-1995 -> custom_region_id 3 -> 3
# Y010TH199_0 ru -> custom_region_id 6 -> 6
# 260249678 eu-ua-1995 -> custom_region_id 3 -> 3
# 32056_П3391ЛГ_0_1 su -> custom_region_id 12 -> 9
# 260600638 eu-ua-2004 -> custom_region_id 2 -> 2
# eu-ua-2004_313815530_0 eu-ua-2004 -> custom_region_id 2 -> 2
# X444AY54_0 ru -> custom_region_id 6 -> 6
# 1_su_208159269_Т3638ОД su -> custom_region_id 12 -> 9
# 260948712 xx-transit -> custom_region_id 5 -> 5
# 260228537 xx-unknown -> custom_region_id 0 -> 0
# 259968490 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero243155205-0 xx-unknown -> custom_region_id 0 -> 0
# 260250223 xx-unknown -> custom_region_id 0 -> 0
# 260020092 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248304152-0 xx-unknown -> custom_region_id 0 -> 0
# 260843689 eu -> custom_region_id 4 -> 4
# 259938502 xx-unknown -> custom_region_id 0 -> 0
# 260118443 eu-ua-2015 -> custom_region_id 1 -> 1
# M581TM116_0 ru -> custom_region_id 6 -> 6
# 260261199 xx-unknown -> custom_region_id 0 -> 0
# H980YE77_0 ru -> custom_region_id 6 -> 6
# 260222027 eu-ua-2004 -> custom_region_id 2 -> 2
# P010AM197_0 ru -> custom_region_id 6 -> 6
# 260072307 eu-ua-2015 -> custom_region_id 1 -> 1
# 3_eu_ua_2015_274922143_AA153IB eu-ua-2015 -> custom_region_id 1 -> 1
# 260614611 xx-transit -> custom_region_id 5 -> 5
# 3_eu_ua_2004_344421472_AMK8B eu-ua-2004 -> custom_region_id 2 -> 2
# 259942105 eu-ua-2015 -> custom_region_id 1 -> 1
# 260121306 eu -> custom_region_id 4 -> 4
# 259939396 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_379915424_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260243160 eu-ua-2004 -> custom_region_id 2 -> 2
# P061TC54_0 ru -> custom_region_id 6 -> 6
# 8121KA su -> custom_region_id 12 -> 9
# 260820893 eu-ua-1995 -> custom_region_id 3 -> 3
# 261441949 eu-ua-1995 -> custom_region_id 3 -> 3
# 260014044 eu-ua-2015 -> custom_region_id 1 -> 1
# 260257173 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero248165912-0 xx-unknown -> custom_region_id 0 -> 0
# 3HPxiTaCuytvA29kbpYFE87Rr0JcXwjI1GUsfmeqMBlzZhO6gV eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 260256276 eu-ua-2004 -> custom_region_id 2 -> 2
# 19809_Р6761ХА_0_1 su -> custom_region_id 12 -> 9
# TB0550AT su -> custom_region_id 12 -> 9
# 260082221 eu-ua-2015 -> custom_region_id 1 -> 1
# 260739778 eu-ua-1995 -> custom_region_id 3 -> 3
# 3_eu_ua_2015_342472539_AA1IH eu-ua-2015 -> custom_region_id 1 -> 1
# 260034889 eu -> custom_region_id 4 -> 4
# 260960139 eu-ua-1995 -> custom_region_id 3 -> 3
# 260254952 eu -> custom_region_id 4 -> 4
# eu-ua-1995_327586627_0 eu-ua-1995 -> custom_region_id 3 -> 3
# 260585120 eu -> custom_region_id 4 -> 4
# 260249752 eu-ua-2015 -> custom_region_id 1 -> 1
# 51263_Д5355СФ_1_1 su -> custom_region_id 12 -> 9
# 260562920 eu -> custom_region_id 4 -> 4
# 260232870 eu-ua-2015 -> custom_region_id 1 -> 1
# 261149237 xx-transit -> custom_region_id 5 -> 5
# 21040_Л2661ТБ_0_1 su -> custom_region_id 12 -> 9
# 259990953 eu -> custom_region_id 4 -> 4
# eAqJ5rUjHbgWun7toF9fDcQaSphTiCY2OyIRwP6EzL3k08XlvM eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# A798EX199_0 ru -> custom_region_id 6 -> 6
# option_zero244919358-0 xx-unknown -> custom_region_id 0 -> 0
# 260029089 eu -> custom_region_id 4 -> 4
# 261437301 eu-ua-1995 -> custom_region_id 3 -> 3
# 41223_М5600ДП_0_1 su -> custom_region_id 12 -> 9
# 260224920 eu-ua-2015 -> custom_region_id 1 -> 1
# 260059581 xx-unknown -> custom_region_id 0 -> 0
# 259937088 xx-unknown -> custom_region_id 0 -> 0
# 260566901 eu-ua-2004 -> custom_region_id 2 -> 2
# 260083767 eu-ua-2015 -> custom_region_id 1 -> 1
# 259470130 eu -> custom_region_id 4 -> 4
# 260582136 eu-ua-2004 -> custom_region_id 2 -> 2
# 256426415 eu -> custom_region_id 4 -> 4
# 260257457 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_327558342_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260097549 eu -> custom_region_id 4 -> 4
# 260940513 xx-transit -> custom_region_id 5 -> 5
# 260070242 eu-ua-2015 -> custom_region_id 1 -> 1
# K393BC46_0 ru -> custom_region_id 6 -> 6
# 261090252 eu-ua-1995 -> custom_region_id 3 -> 3
# 260088479 eu-ua-2015 -> custom_region_id 1 -> 1
# 260116570 xx-unknown -> custom_region_id 0 -> 0
# 260238410 xx-unknown -> custom_region_id 0 -> 0
# 260227527 eu-ua-2015 -> custom_region_id 1 -> 1
# 260225010 eu -> custom_region_id 4 -> 4
# eu-ua-2015_325583320_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 32244_Е0660ЛД_0_1 su -> custom_region_id 12 -> 9
# option_zero245616439-0 xx-unknown -> custom_region_id 0 -> 0
# 58803_Ч5776ЧБ_0_1 su -> custom_region_id 12 -> 9
# T668XE98_0 ru -> custom_region_id 6 -> 6
# YQgkfJiZo6RH0XMO1mbV5exjBP8A2GrDnILUShpEsFwTcv93qu eu-ua-2015 -> custom_region_id 1 -> 1
# 260265475 xx-unknown -> custom_region_id 0 -> 0
# 260229257 eu-ua-2004 -> custom_region_id 2 -> 2
# X282EP64_0 ru -> custom_region_id 6 -> 6
# 260073440 eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2004_320075091_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260677034 xx-unknown -> custom_region_id 0 -> 0
# 260225757 eu -> custom_region_id 4 -> 4
# 260592336 eu-ua-2004 -> custom_region_id 2 -> 2
# Y730AE197_0 ru -> custom_region_id 6 -> 6
# 260234060 eu-ua-2015 -> custom_region_id 1 -> 1
# 13142-main_0 eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# F0810XM su -> custom_region_id 12 -> 9
# 260057626 eu-ua-2015 -> custom_region_id 1 -> 1
# 260079037 eu-ua-2015 -> custom_region_id 1 -> 1
# 90145_Н9029МЯ_0_1 su -> custom_region_id 12 -> 9
# Y058XK150_0 ru -> custom_region_id 6 -> 6
# 260825882 eu-ua-1995 -> custom_region_id 3 -> 3
# 261172743 xx-transit -> custom_region_id 5 -> 5
# 259942396 xx-unknown -> custom_region_id 0 -> 0
# 260047565 eu-ua-2004 -> custom_region_id 2 -> 2
# 260871100 eu-ua-1995 -> custom_region_id 3 -> 3
# 260046243 eu-ua-1995 -> custom_region_id 3 -> 3
# 260749414 xx-transit -> custom_region_id 5 -> 5
# 260001755 eu -> custom_region_id 4 -> 4
# option_zero159334299-0 xx-unknown -> custom_region_id 0 -> 0
# 260031414 eu-ua-2004 -> custom_region_id 2 -> 2
# 260570858 eu -> custom_region_id 4 -> 4
# 259727191 xx-transit -> custom_region_id 5 -> 5
# 260628320 xx-unknown -> custom_region_id 0 -> 0
# 260232310 eu-ua-2015 -> custom_region_id 1 -> 1
# 260055269 eu-ua-2015 -> custom_region_id 1 -> 1
# 258779244source xx-transit -> custom_region_id 5 -> 5
# 260600833 eu -> custom_region_id 4 -> 4
# 261438739 eu-ua-1995 -> custom_region_id 3 -> 3
# 26351_Ц4067ДО_2_1 su -> custom_region_id 12 -> 9
# 260116648 eu-ua-1995 -> custom_region_id 3 -> 3
# 260946289 eu-ua-1995 -> custom_region_id 3 -> 3
# 260238951 eu-ua-2015 -> custom_region_id 1 -> 1
# 260700700 eu-ua-2015 -> custom_region_id 1 -> 1
# 260085545 eu-ua-2015 -> custom_region_id 1 -> 1
# 260008116 eu-ua-2004 -> custom_region_id 2 -> 2
# 260587639 eu-ua-2004 -> custom_region_id 2 -> 2
# 259955366 xx-unknown -> custom_region_id 0 -> 0
# 260245886 xx-unknown -> custom_region_id 0 -> 0
# 261451629 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero153589505-0 xx-unknown -> custom_region_id 0 -> 0
# 260115947 eu-ua-1995 -> custom_region_id 3 -> 3
# 260242676 eu-ua-2004 -> custom_region_id 2 -> 2
# 260038145 eu-ua-2015 -> custom_region_id 1 -> 1
# H854TX71_0 ru -> custom_region_id 6 -> 6
# 260589746 eu -> custom_region_id 4 -> 4
# 260256914 xx-unknown -> custom_region_id 0 -> 0
# 260259188 eu-ua-2004 -> custom_region_id 2 -> 2
# 260124511 xx-unknown -> custom_region_id 0 -> 0
# 260574381 eu-ua-2004 -> custom_region_id 2 -> 2
# H710TX199_0 ru -> custom_region_id 6 -> 6
# 260963770 eu-ua-1995 -> custom_region_id 3 -> 3
# 4379_Ш7421ХА_2_1 su -> custom_region_id 12 -> 9
# 260247633 eu-ua-2004 -> custom_region_id 2 -> 2
# 260235261 xx-unknown -> custom_region_id 0 -> 0
# 42183_М7153ВИ_0_1 su -> custom_region_id 12 -> 9
# 260074507 eu -> custom_region_id 4 -> 4
# 260241996 xx-unknown -> custom_region_id 0 -> 0
# kcCgX5dRQKB1oxLbpP64EAvOjnzHt2h7SD8WIeiaqZGwJ30uyT eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero245352843-0 xx-unknown -> custom_region_id 0 -> 0
# E0680XM su -> custom_region_id 12 -> 9
# 260057364 eu-ua-2004 -> custom_region_id 2 -> 2
# 260070986 eu-ua-2015 -> custom_region_id 1 -> 1
# O864TP54_0 ru -> custom_region_id 6 -> 6
# 260244989 xx-unknown -> custom_region_id 0 -> 0
# 259966412 eu-ua-2004 -> custom_region_id 2 -> 2
# 259941758 eu-ua-2004 -> custom_region_id 2 -> 2
# 260029090 xx-unknown -> custom_region_id 0 -> 0
# 260262210 eu-ua-2015 -> custom_region_id 1 -> 1
# 260124340 xx-unknown -> custom_region_id 0 -> 0
# 260229016 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero249247229-0 xx-unknown -> custom_region_id 0 -> 0
# 260059027 eu-ua-2015 -> custom_region_id 1 -> 1
# 260553457 xx-unknown -> custom_region_id 0 -> 0
# 259958830 eu -> custom_region_id 4 -> 4
# 260241212 xx-unknown -> custom_region_id 0 -> 0
# 260062522 eu-ua-2015 -> custom_region_id 1 -> 1
# 261273828 eu-ua-1995 -> custom_region_id 3 -> 3
# 259996158 eu-ua-2004 -> custom_region_id 2 -> 2
# 3_eu_ua_2015_260706789_AAEMT81AE eu-ua-2015 -> custom_region_id 1 -> 1
# 260258347 eu-ua-2015 -> custom_region_id 1 -> 1
# 260050855 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248704735-0 xx-unknown -> custom_region_id 0 -> 0
# 3834_Я2531ХА_0_1 su -> custom_region_id 12 -> 9
# 260008298 eu-ua-2004 -> custom_region_id 2 -> 2
# 260593432 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero246643262-0 xx-unknown -> custom_region_id 0 -> 0
# 260254351 eu -> custom_region_id 4 -> 4
# 00058XA su -> custom_region_id 12 -> 9
# B672AP35_0 ru -> custom_region_id 6 -> 6
# option_zero247237520-0 xx-unknown -> custom_region_id 0 -> 0
# 260243590 eu-ua-2015 -> custom_region_id 1 -> 1
# 5072-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260240712 eu -> custom_region_id 4 -> 4
# 259934896 xx-unknown -> custom_region_id 0 -> 0
# 261392284 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero247991947-0 xx-unknown -> custom_region_id 0 -> 0
# 260054043 eu-ua-2015 -> custom_region_id 1 -> 1
# 260236669 eu-ua-2004 -> custom_region_id 2 -> 2
# 259959749 eu -> custom_region_id 4 -> 4
# 260113314 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero246807301-0 xx-unknown -> custom_region_id 0 -> 0
# A237EY178_0 ru -> custom_region_id 6 -> 6
# 20065_В5130ХК_0_1 su -> custom_region_id 12 -> 9
# 261322972 xx-transit -> custom_region_id 5 -> 5
# option_zero246705838-0 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_380578970_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260079319 xx-unknown -> custom_region_id 0 -> 0
# 260258792 eu-ua-1995 -> custom_region_id 3 -> 3
# 259985300 eu-ua-2015 -> custom_region_id 1 -> 1
# 260222924 xx-transit -> custom_region_id 5 -> 5
# 261261313 eu-ua-1995 -> custom_region_id 3 -> 3
# 260035034 eu-ua-2015 -> custom_region_id 1 -> 1
# 140156_Е3627ЯТ_0_1 su -> custom_region_id 12 -> 9
# 260266883 eu-ua-2004 -> custom_region_id 2 -> 2
# 260074089 eu-ua-2015 -> custom_region_id 1 -> 1
# 259961033 eu -> custom_region_id 4 -> 4
# 260258365 eu-ua-2015 -> custom_region_id 1 -> 1
# 261181717 xx-transit -> custom_region_id 5 -> 5
# 259958622 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero246104189-0 xx-unknown -> custom_region_id 0 -> 0
# 34214_О4090ОМ_0_1 su -> custom_region_id 12 -> 9
# 12232_З5625ХА_0_1 su -> custom_region_id 12 -> 9
# 32130_М7409КР_0_1 su -> custom_region_id 12 -> 9
# 3_eu_ua_2015_235057921_BC93AE eu-ua-2015 -> custom_region_id 1 -> 1
# 259938511 eu -> custom_region_id 4 -> 4
# 259992002 eu-ua-2004 -> custom_region_id 2 -> 2
# 119476_С9428ДП_0_1 su -> custom_region_id 12 -> 9
# 259998618 eu-ua-2004 -> custom_region_id 2 -> 2
# 259944085 xx-unknown -> custom_region_id 0 -> 0
# B607BK102_0 ru -> custom_region_id 6 -> 6
# 25571_Б9580ХА_0_1 su -> custom_region_id 12 -> 9
# option_zero120166070-0 xx-unknown -> custom_region_id 0 -> 0
# 259969700 eu-ua-2004 -> custom_region_id 2 -> 2
# 26303_Я9439ПК_0_1 su -> custom_region_id 12 -> 9
# jDt0TC5bJsq8cK2lYFBez6ivZ9xUNIMR3XukPHQWoVrSEmyLfn eu-ua-2004 -> custom_region_id 2 -> 2
# 260734848 eu-ua-1995 -> custom_region_id 3 -> 3
# option_zero247235926-0 xx-unknown -> custom_region_id 0 -> 0
# 260094339 xx-unknown -> custom_region_id 0 -> 0
# 261295707 xx-unknown -> custom_region_id 0 -> 0
# 50811_И9401ДП_0_1 su -> custom_region_id 12 -> 9
# ebV3zuHCAY6nkZrdFWmpv142oITSOwLixt8y7QEMGRBNUJ5gP0 xx-transit -> custom_region_id 5 -> 5
# 260276210 eu-ua-2004 -> custom_region_id 2 -> 2
# K333HX177_0 ru -> custom_region_id 6 -> 6
# option_zero246944937-0 xx-unknown -> custom_region_id 0 -> 0
# 260561720 eu-ua-2004 -> custom_region_id 2 -> 2
# KM0vV3wF9nRlODQWeUa4J7pBYP5xLcNI8TzoChg61bdimSkGXy eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# option_zero247850839-0 xx-unknown -> custom_region_id 0 -> 0
# 259995776 eu-ua-2004 -> custom_region_id 2 -> 2
# 93909_В1450ХІ_0_1 su -> custom_region_id 12 -> 9
# 260089512 eu-ua-2015 -> custom_region_id 1 -> 1
# 260716805 eu-ua-1995 -> custom_region_id 3 -> 3
# 259964802 eu -> custom_region_id 4 -> 4
# K942XT46_0 ru -> custom_region_id 6 -> 6
# 260237890 eu-ua-2015 -> custom_region_id 1 -> 1
# 28599_Т7703СА_0_1 su -> custom_region_id 12 -> 9
# 260031485 xx-unknown -> custom_region_id 0 -> 0
# option_zero244792025-0 xx-unknown -> custom_region_id 0 -> 0
# 260073354 eu-ua-2015 -> custom_region_id 1 -> 1
# 259969211 eu -> custom_region_id 4 -> 4
# X045PX54_0 ru -> custom_region_id 6 -> 6
# 260238622 eu-ua-2015 -> custom_region_id 1 -> 1
# 260801718 eu-ua-1995 -> custom_region_id 3 -> 3
# 1779ON su -> custom_region_id 12 -> 9
# 260570487 eu-ua-2004 -> custom_region_id 2 -> 2
# 101477_4619МББ_0_1 su -> custom_region_id 12 -> 9
# 260097745 eu-ua-2004 -> custom_region_id 2 -> 2
# eu-ua-2015_380665848_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260958146 eu-ua-2004 -> custom_region_id 2 -> 2
# 260086371 eu-ua-2004 -> custom_region_id 2 -> 2
# 260605702 eu-ua-2004 -> custom_region_id 2 -> 2
# 259970810 xx-unknown -> custom_region_id 0 -> 0
# 260227971 xx-unknown -> custom_region_id 0 -> 0
# option_zero245408038-0 xx-unknown -> custom_region_id 0 -> 0
# 260228264 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_326471871_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 261332487 xx-transit -> custom_region_id 5 -> 5
# 260249327 xx-unknown -> custom_region_id 0 -> 0
# 259958636 eu-ua-2004 -> custom_region_id 2 -> 2
# 260554514 eu-ua-1995 -> custom_region_id 3 -> 3
# 260245189 eu-ua-2015 -> custom_region_id 1 -> 1
# 259938536 xx-unknown -> custom_region_id 0 -> 0
# 259978455 eu-ua-2004 -> custom_region_id 2 -> 2
# 260699172 eu-ua-1995 -> custom_region_id 3 -> 3
# 17cOX3QVkeYTuWdgZPRJo6arBIy4twADLSEmU0NfFnbshi2C5l eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero239757363-0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260931177 eu-ua-1995 -> custom_region_id 3 -> 3
# 260240779 eu-ua-2015 -> custom_region_id 1 -> 1
# 260046392 xx-transit -> custom_region_id 5 -> 5
# option_zero244945177-0 xx-unknown -> custom_region_id 0 -> 0
# 260222968 eu-ua-2004 -> custom_region_id 2 -> 2
# B401KH96_0 ru -> custom_region_id 6 -> 6
# X200OM24_0 ru -> custom_region_id 6 -> 6
# A156KM152_0 ru -> custom_region_id 6 -> 6
# 259975953 eu -> custom_region_id 4 -> 4
# 260082498 eu-ua-2004 -> custom_region_id 2 -> 2
# 260919673 eu-ua-1995 -> custom_region_id 3 -> 3
# 3_eu_ua_2004_213589663_BH1812AE eu-ua-2004 -> custom_region_id 2 -> 2
# 260033500 eu-ua-2015 -> custom_region_id 1 -> 1
# 260669309 eu-ua-2015 -> custom_region_id 1 -> 1
# 260145225 eu-ua-1995 -> custom_region_id 3 -> 3
# 261013786 eu-ua-1995 -> custom_region_id 3 -> 3
# 260262151 eu-ua-2015 -> custom_region_id 1 -> 1
# 260045753 eu -> custom_region_id 4 -> 4
# 259961635 eu -> custom_region_id 4 -> 4
# option_zero245694396-0 xx-unknown -> custom_region_id 0 -> 0
# K739XA40_0 ru -> custom_region_id 6 -> 6
# 259999914 eu -> custom_region_id 4 -> 4
# 260768444 eu-ua-1995 -> custom_region_id 3 -> 3
# 260038013 eu-ua-2004 -> custom_region_id 2 -> 2
# 261186949 xx-transit -> custom_region_id 5 -> 5
# option_zero171882157-0 xx-unknown -> custom_region_id 0 -> 0
# 260248191 eu-ua-2004 -> custom_region_id 2 -> 2
# 260236386 xx-unknown -> custom_region_id 0 -> 0
# 260257742 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248533374-0 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2015_348734521_AM9311TP eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2015_380911219_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260015270 eu-ua-1995 -> custom_region_id 3 -> 3
# O600AK124_0 ru -> custom_region_id 6 -> 6
# 260222837 eu -> custom_region_id 4 -> 4
# 259739954 eu-ua-1995 -> custom_region_id 3 -> 3
# K202KP62_0 ru -> custom_region_id 6 -> 6
# 260016191 eu-ua-2004 -> custom_region_id 2 -> 2
# 4172_Х2671ХА_0_1 su -> custom_region_id 12 -> 9
# 260083497 eu-ua-2004 -> custom_region_id 2 -> 2
# P009TP52_0 ru -> custom_region_id 6 -> 6
# 260253897 xx-unknown -> custom_region_id 0 -> 0
# 260240047 eu-ua-2004 -> custom_region_id 2 -> 2
# 260028994 xx-unknown -> custom_region_id 0 -> 0
# option_zero164767101-0 xx-unknown -> custom_region_id 0 -> 0
# 260263299 xx-unknown -> custom_region_id 0 -> 0
# 260018017 eu -> custom_region_id 4 -> 4
# 260552742 xx-unknown -> custom_region_id 0 -> 0
# 258259060 eu -> custom_region_id 4 -> 4
# 260250984 eu -> custom_region_id 4 -> 4
# 260236324 xx-unknown -> custom_region_id 0 -> 0
# 260564186 eu -> custom_region_id 4 -> 4
# 10623_Б0622ВО_0_1 su -> custom_region_id 12 -> 9
# 259979122 xx-unknown -> custom_region_id 0 -> 0
# 260561719 eu-ua-2004 -> custom_region_id 2 -> 2
# B564MY61_0 ru -> custom_region_id 6 -> 6
# 259995899 eu-ua-2015 -> custom_region_id 1 -> 1
# 102146_И7535МИ_0_1 su -> custom_region_id 12 -> 9
# 260242232 eu-ua-2015 -> custom_region_id 1 -> 1
# 260257189 eu-ua-2015 -> custom_region_id 1 -> 1
# 260042491 eu-ua-1995 -> custom_region_id 3 -> 3
# 17678_Г8964ХМ_0_1 su -> custom_region_id 12 -> 9
# 260800821 eu-ua-1995 -> custom_region_id 3 -> 3
# 259972196 eu-ua-2015 -> custom_region_id 1 -> 1
# P001TT64_0 ru -> custom_region_id 6 -> 6
# 3_eu_ua_2015_193908669_AA7707IK eu-ua-2015 -> custom_region_id 1 -> 1
# 260069623 eu-ua-2004 -> custom_region_id 2 -> 2
# 260239838 xx-unknown -> custom_region_id 0 -> 0
# 260032142 eu-ua-2004 -> custom_region_id 2 -> 2
# 261409684 xx-transit -> custom_region_id 5 -> 5
# 260931220 xx-transit -> custom_region_id 5 -> 5
# 260078262 eu-ua-2015 -> custom_region_id 1 -> 1
# 260118820 eu-ua-2015 -> custom_region_id 1 -> 1
# O509OO98_0 ru -> custom_region_id 6 -> 6
# option_zero248257893-0 eu -> custom_region_id 4 -> 4
# CA8969OK su -> custom_region_id 12 -> 9
# eu-ua-2015_325906126_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260603344 eu -> custom_region_id 4 -> 4
# option_zero247546635-0 xx-unknown -> custom_region_id 0 -> 0
# 259942624 eu-ua-2004 -> custom_region_id 2 -> 2
# LjXRpF94hcbQmtdNIrlDwUAS51ekVTgYGKiaW3uzoC6OH827yJ eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 93023_А6203ХІ_0_1 su -> custom_region_id 12 -> 9
# eu-ua-2015_327251870_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260068133 eu-ua-2015 -> custom_region_id 1 -> 1
# 260242775 eu-ua-2015 -> custom_region_id 1 -> 1
# 260222435 eu-ua-2015 -> custom_region_id 1 -> 1
# 3_eu_ua_2015_210709734_AM9917AE eu-ua-2015 -> custom_region_id 1 -> 1
# 260559645 eu-ua-1995 -> custom_region_id 3 -> 3
# 260555729 eu-ua-2004 -> custom_region_id 2 -> 2
# 260123182 eu-ua-2015 -> custom_region_id 1 -> 1
# 260264050 xx-unknown -> custom_region_id 0 -> 0
# 261393891 xx-unknown -> custom_region_id 0 -> 0
# FEY9vRWhD8epKg0Z13n6dbGBPsXx2uCyUmfSQokt5JqcVaN4AL eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# eu-ua-2004_326244899_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260038252 eu-ua-2015 -> custom_region_id 1 -> 1
# 260252215 eu-ua-2004 -> custom_region_id 2 -> 2
# 260728953 eu-ua-2015 -> custom_region_id 1 -> 1
# 260675585 eu-ua-2015 -> custom_region_id 1 -> 1
# 260036338 xx-unknown -> custom_region_id 0 -> 0
# 6438_Т2310ХА_0_1 su -> custom_region_id 12 -> 9
# 260270557 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero235626363-0 xx-unknown -> custom_region_id 0 -> 0
# O285MO174_0 ru -> custom_region_id 6 -> 6
# 260264225 xx-unknown -> custom_region_id 0 -> 0
# 260005355 eu -> custom_region_id 4 -> 4
# option_zero248412965-0 xx-unknown -> custom_region_id 0 -> 0
# B080XE72_1 ru -> custom_region_id 6 -> 6
# A444AH21_0 ru -> custom_region_id 6 -> 6
# 260087028 eu-ua-1995 -> custom_region_id 3 -> 3
# 260084596 eu-ua-2015 -> custom_region_id 1 -> 1
# 261299139 eu-ua-1995 -> custom_region_id 3 -> 3
# 260817172 eu-ua-1995 -> custom_region_id 3 -> 3
# K391HO46_0 ru -> custom_region_id 6 -> 6
# CcEqyTZOD2fHupNwY4erUnP3zWLsFBtaR1Jdo57m9vG8kAIbSQ eu-ua-2015 -> custom_region_id 1 -> 1
# T848KE54_0 ru -> custom_region_id 6 -> 6
# 54521_Д0170ОА_0_1 su -> custom_region_id 12 -> 9
# 125574_Т8176ЛД_0_1 su -> custom_region_id 12 -> 9
# 261473130 xx-unknown -> custom_region_id 0 -> 0
# eu-ua-2015_381064241_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 259935747 xx-unknown -> custom_region_id 0 -> 0
# 261436802 eu-ua-1995 -> custom_region_id 3 -> 3
# 261097949 xx-unknown -> custom_region_id 0 -> 0
# 260598793 eu-ua-2004 -> custom_region_id 2 -> 2
# 4839_В1598СВ_0_1 su -> custom_region_id 12 -> 9
# 261486334 eu-ua-1995 -> custom_region_id 3 -> 3
# 260685154 xx-unknown -> custom_region_id 0 -> 0
# 260560548 eu -> custom_region_id 4 -> 4
# 260087231 eu-ua-2004 -> custom_region_id 2 -> 2
# 260262381 xx-unknown -> custom_region_id 0 -> 0
# 260918658 eu -> custom_region_id 4 -> 4
# 260221934 eu-ua-2004 -> custom_region_id 2 -> 2
# 260241563 xx-unknown -> custom_region_id 0 -> 0
# 260010497 eu-ua-2004 -> custom_region_id 2 -> 2
# eu-ua-2015_380676332_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260230950 eu-ua-2015 -> custom_region_id 1 -> 1
# Y555XM74_0 ru -> custom_region_id 6 -> 6
# 3_eu_ua_2015_288883279_AEM30AE eu-ua-2015 -> custom_region_id 1 -> 1
# 259966540 eu-ua-2015 -> custom_region_id 1 -> 1
# 260075800 eu-ua-2004 -> custom_region_id 2 -> 2
# 260254154 eu-ua-2004 -> custom_region_id 2 -> 2
# 134085_К3953ЯК_1_1 su -> custom_region_id 12 -> 9
# 260261567 xx-unknown -> custom_region_id 0 -> 0
# 260226001 eu -> custom_region_id 4 -> 4
# 28157_К3875ЛД_0_1 su -> custom_region_id 12 -> 9
# 259995288 eu-ua-2004 -> custom_region_id 2 -> 2
# 3_eu_ua_2015_275775342_AAC117AE eu-ua-2015 -> custom_region_id 1 -> 1
# E107KY46_0 ru -> custom_region_id 6 -> 6
# 259989506 eu-ua-2004 -> custom_region_id 2 -> 2
# 259998195 eu-ua-2004 -> custom_region_id 2 -> 2
# 3_eu_ua_2015_350632278_CE087AE eu-ua-2015 -> custom_region_id 1 -> 1
# 260229596 eu-ua-2015 -> custom_region_id 1 -> 1
# 260847981 xx-transit -> custom_region_id 5 -> 5
# option_zero245400394-0 xx-unknown -> custom_region_id 0 -> 0
# 259967204 eu-ua-2015 -> custom_region_id 1 -> 1
# 260812256 eu-ua-1995 -> custom_region_id 3 -> 3
# 260247589 xx-unknown -> custom_region_id 0 -> 0
# DCdGcLFQWHyOrPxTzgVk9bN1o6nfsuAatpYU4RiJ07K3ZjelqE eu-ua-2004 -> custom_region_id 2 -> 2
# 259470092 eu -> custom_region_id 4 -> 4
# 260225794 eu-ua-2015 -> custom_region_id 1 -> 1
# 259938129 eu -> custom_region_id 4 -> 4
# 260594820 eu -> custom_region_id 4 -> 4
# 259996619 eu-ua-2015 -> custom_region_id 1 -> 1
# eu-ua-2015_381057898_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260252689 eu-ua-2004 -> custom_region_id 2 -> 2
# 260233337 xx-unknown -> custom_region_id 0 -> 0
# 260582619 eu-ua-2004 -> custom_region_id 2 -> 2
# 260613847 xx-unknown -> custom_region_id 0 -> 0
# 260829258 eu-ua-1995 -> custom_region_id 3 -> 3
# 261449670 eu-ua-1995 -> custom_region_id 3 -> 3
# 53342_Е1609КИ_0_1 su -> custom_region_id 12 -> 9
# 260074045 eu-ua-1995 -> custom_region_id 3 -> 3
# 260002458 eu-ua-2015 -> custom_region_id 1 -> 1
# 104224_В4785ХІ_0_1 su -> custom_region_id 12 -> 9
# 260229172 xx-unknown -> custom_region_id 0 -> 0
# 260553051 xx-unknown -> custom_region_id 0 -> 0
# 260096455 eu-ua-2004 -> custom_region_id 2 -> 2
# 260076206 eu -> custom_region_id 4 -> 4
# 260251251 xx-unknown -> custom_region_id 0 -> 0
# 54130_Р0207КИ_0_1 su -> custom_region_id 12 -> 9
# 260650708 eu-ua-1995 -> custom_region_id 3 -> 3
# 260265087 eu-ua-2004 -> custom_region_id 2 -> 2
# 259981860 eu-ua-2015 -> custom_region_id 1 -> 1
# 260266021 xx-unknown -> custom_region_id 0 -> 0
# 260006838 eu-ua-2004 -> custom_region_id 2 -> 2
# 260010536 eu-ua-2004 -> custom_region_id 2 -> 2
# O886TM54_0 ru -> custom_region_id 6 -> 6
# 259504775euro.jpegzone1 eu-ua-1995 -> custom_region_id 3 -> 3
# 260265749 xx-unknown -> custom_region_id 0 -> 0
# 11057_К7830БУ_0_1 su -> custom_region_id 12 -> 9
# 104348_А2329РМ_0_1 su -> custom_region_id 12 -> 9
# eu-ua-2015_380731335_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260057274 eu-ua-2015 -> custom_region_id 1 -> 1
# 260261939 xx-unknown -> custom_region_id 0 -> 0
# 259976253 eu -> custom_region_id 4 -> 4
# 98897_В7683ХІ_0_1 su -> custom_region_id 12 -> 9
# 260056847 eu -> custom_region_id 4 -> 4
# 260029478 xx-unknown -> custom_region_id 0 -> 0
# 260070162 eu -> custom_region_id 4 -> 4
# 260241225 eu-ua-2004 -> custom_region_id 2 -> 2
# 27247_А0597ВЛ_0_1 su -> custom_region_id 12 -> 9
# 260029507 eu -> custom_region_id 4 -> 4
# 121454_Л3466КК_1_1 su -> custom_region_id 12 -> 9
# 260065553 eu-ua-2004 -> custom_region_id 2 -> 2
# 0381HKM su -> custom_region_id 12 -> 9
# 241786152 eu-ua-2004 -> custom_region_id 2 -> 2
# 260257111 eu -> custom_region_id 4 -> 4
# 260233402 xx-unknown -> custom_region_id 0 -> 0
# 260597404 eu-ua-1995 -> custom_region_id 3 -> 3
# 260243647 xx-unknown -> custom_region_id 0 -> 0
# 261196153 xx-unknown -> custom_region_id 0 -> 0
# yVRU3wetnpHlOGA8NmgSrQZh42BzoT1XFPsE5WbkcIu7KixvDa eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# option_zero247453296-0 xx-unknown -> custom_region_id 0 -> 0
# 261161653 xx-transit -> custom_region_id 5 -> 5
# option_zero248904744-0 eu -> custom_region_id 4 -> 4
# 261052182 xx-transit -> custom_region_id 5 -> 5
# 260230078 eu-ua-2004 -> custom_region_id 2 -> 2
# B999EX40_0 ru -> custom_region_id 6 -> 6
# 260062736 eu-ua-2015 -> custom_region_id 1 -> 1
# 260839693 eu-ua-1995 -> custom_region_id 3 -> 3
# eu-ua-2015_325904508_0 eu-ua-2015 -> custom_region_id 1 -> 1
# H100XK29_0 ru -> custom_region_id 6 -> 6
# 260009786 eu-ua-2015 -> custom_region_id 1 -> 1
# 7775-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260874023 xx-unknown -> custom_region_id 0 -> 0
# M004BP54_0 ru -> custom_region_id 6 -> 6
# 56275_Д4363ДО_0_1 su -> custom_region_id 12 -> 9
# 29814_В3765ЛГ_0_1 su -> custom_region_id 12 -> 9
# 260595005 eu-ua-2004 -> custom_region_id 2 -> 2
# 260067502 eu-ua-2015 -> custom_region_id 1 -> 1
# 259992956 eu -> custom_region_id 4 -> 4
# 260224242 eu-ua-2004 -> custom_region_id 2 -> 2
# 259696657 eu-ua-1995 -> custom_region_id 3 -> 3
# 12749-main_0 eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 6194-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260674741 xx-transit -> custom_region_id 5 -> 5
# 260034712 eu-ua-2015 -> custom_region_id 1 -> 1
# P199YO98_0 ru -> custom_region_id 6 -> 6
# 260245648 xx-unknown -> custom_region_id 0 -> 0
# 260237534 eu -> custom_region_id 4 -> 4
# 261259805 eu-ua-1995 -> custom_region_id 3 -> 3
# 260066819 eu-ua-2015 -> custom_region_id 1 -> 1
# E0700XM su -> custom_region_id 12 -> 9
# eu-ua-2015_380239217_0 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero247423952-0 xx-unknown -> custom_region_id 0 -> 0
# option_zero245402338-0 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2015_282443443_AE7707AK eu-ua-2015 -> custom_region_id 1 -> 1
# 259956052 eu-ua-2015 -> custom_region_id 1 -> 1
# 260223319 xx-unknown -> custom_region_id 0 -> 0
# 260245956 eu-ua-2015 -> custom_region_id 1 -> 1
# 260252411 xx-unknown -> custom_region_id 0 -> 0
# 135_А9648КЖ_0_1 su -> custom_region_id 12 -> 9
# O970TX54_0 ru -> custom_region_id 6 -> 6
# eu-ua-2015_324271120_0 eu-ua-2004 -> custom_region_id 2 -> 2
# 260972613 eu-ua-1995 -> custom_region_id 3 -> 3
# eu-ua-2015_327550931_0 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero247994831-0 xx-unknown -> custom_region_id 0 -> 0
# 260095335 eu-ua-1995 -> custom_region_id 3 -> 3
# 31236_Е2612РЯ_1_1 su -> custom_region_id 12 -> 9
# eu-ua-2015_380509052_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 260223761 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero246187843-0 xx-unknown -> custom_region_id 0 -> 0
# 260227551 xx-unknown -> custom_region_id 0 -> 0
# 261244932 xx-transit -> custom_region_id 5 -> 5
# 259961933 eu-ua-2015 -> custom_region_id 1 -> 1
# 4404OA su -> custom_region_id 12 -> 9
# option_zero245834295-0 xx-unknown -> custom_region_id 0 -> 0
# X409MM54_0 ru -> custom_region_id 6 -> 6
# 16789_Ж1924ВО_0_1 su -> custom_region_id 12 -> 9
# option_zero248380693-0 xx-unknown -> custom_region_id 0 -> 0
# 260246824 eu-ua-2015 -> custom_region_id 1 -> 1
# 260597804 eu -> custom_region_id 4 -> 4
# 260257443 eu-ua-2015 -> custom_region_id 1 -> 1
# 259984578 eu -> custom_region_id 4 -> 4
# 260243709 xx-unknown -> custom_region_id 0 -> 0
# 260030979 xx-unknown -> custom_region_id 0 -> 0
# 260240302 xx-unknown -> custom_region_id 0 -> 0
# F8767KU su -> custom_region_id 12 -> 9
# 260248806 eu-ua-2004 -> custom_region_id 2 -> 2
# 260222225 eu-ua-2004 -> custom_region_id 2 -> 2
# 260114820 eu -> custom_region_id 4 -> 4
# 260031466 eu-ua-2004 -> custom_region_id 2 -> 2
# 260596748 eu-ua-2004 -> custom_region_id 2 -> 2
# 261197391 xx-transit -> custom_region_id 5 -> 5
# 260070671 eu-ua-2015 -> custom_region_id 1 -> 1
# 260657909 eu-ua-1995 -> custom_region_id 3 -> 3
# 3_eu_ua_2004_264947317_BH5386AE eu-ua-2004 -> custom_region_id 2 -> 2
# eu-ua-2015_380300843_0 eu-ua-2015 -> custom_region_id 1 -> 1
# 259979596 eu-ua-2004 -> custom_region_id 2 -> 2
# 260594444 eu-ua-2004 -> custom_region_id 2 -> 2
# 260084644 eu-ua-2015 -> custom_region_id 1 -> 1
# 260240964 xx-unknown -> custom_region_id 0 -> 0
# 135995_О6018ЯТ_0_1 su -> custom_region_id 12 -> 9
# 260076805 eu-ua-2015 -> custom_region_id 1 -> 1
# 7hBbMicaLRxpJyIFCrZqmldvK23TGgN8XPW4uoYE5SsjVeQ6zn eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# E832YH71_0 ru -> custom_region_id 6 -> 6
# 260056843 eu -> custom_region_id 4 -> 4
# 43009_Л7920МН_0_1 su -> custom_region_id 12 -> 9
# 7E6Pgb9BXGKrjAthiUpVJMl5fSO3qRca0eyWxFCzYsZ4dwkmoI eu-ua-2015 -> custom_region_id 1 -> 1
# 3_eu_ua_2015_352820407_AI1AK eu-ua-2015 -> custom_region_id 1 -> 1
# 260248314 eu -> custom_region_id 4 -> 4
# 260260913 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2004_195970277_AH16A eu-ua-2004 -> custom_region_id 2 -> 2
# 260272576 eu-ua-2004 -> custom_region_id 2 -> 2
# 57359_В4740МИ_0_1 su -> custom_region_id 12 -> 9
# 260881768 eu-ua-1995 -> custom_region_id 3 -> 3
# ...
# 260028366 eu-ua-2015 -> custom_region_id 1 -> 1
# 259994581 eu-ua-2004 -> custom_region_id 2 -> 2
# 260231291 eu-ua-2015 -> custom_region_id 1 -> 1
# 3082-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260006230 eu -> custom_region_id 4 -> 4
# 259967783 xx-transit -> custom_region_id 5 -> 5
# 259933210 eu -> custom_region_id 4 -> 4
# 260562206 eu -> custom_region_id 4 -> 4
# 260076530 eu-ua-2004 -> custom_region_id 2 -> 2
# H222AH190_0 ru -> custom_region_id 6 -> 6
# 260240613 eu -> custom_region_id 4 -> 4
# 260039669 eu -> custom_region_id 4 -> 4
# 87544_Ж4880БН_0_1 su -> custom_region_id 12 -> 9
# 260012442 eu -> custom_region_id 4 -> 4
# 259942953 eu-ua-1995 -> custom_region_id 3 -> 3
# 259938500 xx-unknown -> custom_region_id 0 -> 0
# 261033927 eu-ua-2004 -> custom_region_id 2 -> 2
# 260228357 xx-transit -> custom_region_id 5 -> 5
# 260591005 xx-unknown -> custom_region_id 0 -> 0
# 260228592 eu-ua-2004 -> custom_region_id 2 -> 2
# 260798361 eu-ua-1995 -> custom_region_id 3 -> 3
# 259957048 eu -> custom_region_id 4 -> 4
# 260086464 eu-ua-1995 -> custom_region_id 3 -> 3
# 260025865 eu-ua-2015 -> custom_region_id 1 -> 1
# P550YY24_0 ru -> custom_region_id 6 -> 6
# 260028730 eu-ua-2015 -> custom_region_id 1 -> 1
# 260014618 eu-ua-1995 -> custom_region_id 3 -> 3
# 260559245 eu -> custom_region_id 4 -> 4
# 261387669 xx-transit -> custom_region_id 5 -> 5
# 260072649 eu-ua-2015 -> custom_region_id 1 -> 1
# 260021078 eu-ua-2015 -> custom_region_id 1 -> 1
# 260249829 eu-ua-2015 -> custom_region_id 1 -> 1
# 260247416 xx-unknown -> custom_region_id 0 -> 0
# 260744895 eu-ua-2004 -> custom_region_id 2 -> 2
# 260194671 eu-ua-1995 -> custom_region_id 3 -> 3
# 261165893 eu-ua-1995 -> custom_region_id 3 -> 3
# 17392_Ц8930ХА_1_1 su -> custom_region_id 12 -> 9
# 259976816 eu -> custom_region_id 4 -> 4
# 259962348 xx-unknown -> custom_region_id 0 -> 0
# 259980552 eu -> custom_region_id 4 -> 4
# 260029552 xx-unknown -> custom_region_id 0 -> 0
# 261430253 eu-ua-1995 -> custom_region_id 3 -> 3
# 260257133 eu-ua-1995 -> custom_region_id 3 -> 3
# 260265430 xx-unknown -> custom_region_id 0 -> 0
# 126115_М4354КІ_0_1 su -> custom_region_id 12 -> 9
# 260185298 eu-ua-1995 -> custom_region_id 3 -> 3
# 260242776 eu-ua-2015 -> custom_region_id 1 -> 1
# 260187509 eu-ua-1995 -> custom_region_id 3 -> 3
# 260234447 xx-unknown -> custom_region_id 0 -> 0
# A439AA121_0 ru -> custom_region_id 6 -> 6
# 259858587 eu-ua-1995 -> custom_region_id 3 -> 3
# 260227319 eu-ua-2004 -> custom_region_id 2 -> 2
# 260255712 eu-ua-2015 -> custom_region_id 1 -> 1
# 8590_Д9594ХА_0_1 su -> custom_region_id 12 -> 9
# 260222888 eu-ua-2015 -> custom_region_id 1 -> 1
# 260251716 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero164767288-0 xx-unknown -> custom_region_id 0 -> 0
# 260099841 eu -> custom_region_id 4 -> 4
# 260256827 eu-ua-2015 -> custom_region_id 1 -> 1
# 17299_М5109ТЛ_0_1 su -> custom_region_id 12 -> 9
# 6366_Ш4903МО_0_1 su -> custom_region_id 12 -> 9
# 260259134 xx-unknown -> custom_region_id 0 -> 0
# 260004958 eu -> custom_region_id 4 -> 4
# 260005196 eu-ua-2015 -> custom_region_id 1 -> 1
# 260562334 eu -> custom_region_id 4 -> 4
# 260056086 eu -> custom_region_id 4 -> 4
# 260226248 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero248731744-0 xx-unknown -> custom_region_id 0 -> 0
# 259985354 eu-ua-2015 -> custom_region_id 1 -> 1
# 260042575 eu-ua-2004 -> custom_region_id 2 -> 2
# 260554003 xx-unknown -> custom_region_id 0 -> 0
# 260303784 eu-ua-2004 -> custom_region_id 2 -> 2
# 259946286 eu -> custom_region_id 4 -> 4
# 260088019 eu-ua-2004 -> custom_region_id 2 -> 2
# 260262395 eu-ua-2004 -> custom_region_id 2 -> 2
# 260038378 eu-ua-1995 -> custom_region_id 3 -> 3
# 260262186 xx-unknown -> custom_region_id 0 -> 0
# 260232449 eu -> custom_region_id 4 -> 4
# 260029473 xx-unknown -> custom_region_id 0 -> 0
# 261002497 xx-unknown -> custom_region_id 0 -> 0
# 260081187 eu-ua-2004 -> custom_region_id 2 -> 2
# 260077484 eu-ua-2015 -> custom_region_id 1 -> 1
# 259969130 xx-unknown -> custom_region_id 0 -> 0
# 260589773 eu-ua-2004 -> custom_region_id 2 -> 2
# 260253343 eu-ua-2004 -> custom_region_id 2 -> 2
# QnEF5AO3ZDPvB0wmcuiGCxUMpseHjKYbWo9tIflT1k26zJryga eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260050369 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero247627861-0 xx-unknown -> custom_region_id 0 -> 0
# 260553057 xx-unknown -> custom_region_id 0 -> 0
# 261166708 eu-ua-2004 -> custom_region_id 2 -> 2
# 260240300 xx-unknown -> custom_region_id 0 -> 0
# 260595639 eu-ua-2004 -> custom_region_id 2 -> 2
# K699KK31_0 ru -> custom_region_id 6 -> 6
# 260238013 eu-ua-2004 -> custom_region_id 2 -> 2
# option_zero247235934-0 xx-unknown -> custom_region_id 0 -> 0
# 260001816 eu -> custom_region_id 4 -> 4
# option_zero247773031-0 xx-unknown -> custom_region_id 0 -> 0
# 260555170 eu-ua-2004 -> custom_region_id 2 -> 2
# 261418012 eu-ua-1995 -> custom_region_id 3 -> 3
# 260223924 eu -> custom_region_id 4 -> 4
# 260246274 xx-unknown -> custom_region_id 0 -> 0
# 259994764 xx-transit -> custom_region_id 5 -> 5
# 259997098 eu-ua-2015 -> custom_region_id 1 -> 1
# 260080844 eu-ua-2004 -> custom_region_id 2 -> 2
# 260262006 eu-ua-1995 -> custom_region_id 3 -> 3
# 261457744 eu-ua-1995 -> custom_region_id 3 -> 3
# 260257146 eu-ua-2004 -> custom_region_id 2 -> 2
# 260551937 xx-unknown -> custom_region_id 0 -> 0
# 260653940 eu-ua-1995 -> custom_region_id 3 -> 3
# 261248514 eu-ua-1995 -> custom_region_id 3 -> 3
# 261013792 eu-ua-1995 -> custom_region_id 3 -> 3
# 260756745 eu-ua-1995 -> custom_region_id 3 -> 3
# 260058123 eu-ua-2015 -> custom_region_id 1 -> 1
# 259968678 eu-ua-2015 -> custom_region_id 1 -> 1
# 260801966 eu-ua-1995 -> custom_region_id 3 -> 3
# 260004843 eu-ua-2015 -> custom_region_id 1 -> 1
# 3271-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260234694 xx-unknown -> custom_region_id 0 -> 0
# 259958842 eu -> custom_region_id 4 -> 4
# 260603156 eu-ua-2004 -> custom_region_id 2 -> 2
# 259987198 eu-ua-2015 -> custom_region_id 1 -> 1
# 260259109 xx-unknown -> custom_region_id 0 -> 0
# 260077167 eu-ua-2004 -> custom_region_id 2 -> 2
# 260043723 eu-ua-1995 -> custom_region_id 3 -> 3
# 260259557 eu-ua-2004 -> custom_region_id 2 -> 2
# 261311943 eu-ua-1995 -> custom_region_id 3 -> 3
# 260256065 xx-unknown -> custom_region_id 0 -> 0
# 261073371 xx-transit -> custom_region_id 5 -> 5
# 3_eu_ua_2015_300417729_BX109IB eu-ua-2015 -> custom_region_id 1 -> 1
# 260056020 eu -> custom_region_id 4 -> 4
# 261248515 eu-ua-1995 -> custom_region_id 3 -> 3
# 260008990 xx-unknown -> custom_region_id 0 -> 0
# 260238515 xx-unknown -> custom_region_id 0 -> 0
# 260567689 eu-ua-2004 -> custom_region_id 2 -> 2
# 3_eu_ua_2015_348607420_BH07IA eu-ua-2015 -> custom_region_id 1 -> 1
# 260633361 xx-transit -> custom_region_id 5 -> 5
# 260071743 eu-ua-2015 -> custom_region_id 1 -> 1
# 260063178 eu-ua-2015 -> custom_region_id 1 -> 1
# 260256017 xx-unknown -> custom_region_id 0 -> 0
# 259988786 eu -> custom_region_id 4 -> 4
# 259984887 eu-ua-2015 -> custom_region_id 1 -> 1
# 260076653 eu-ua-2015 -> custom_region_id 1 -> 1
# 95177_В7553ХІ_0_1 su -> custom_region_id 12 -> 9
# 259740040 eu-ua-1995 -> custom_region_id 3 -> 3
# 260121312 eu -> custom_region_id 4 -> 4
# 260247550 xx-unknown -> custom_region_id 0 -> 0
# 259967305 eu -> custom_region_id 4 -> 4
# 260123351 eu-ua-2015 -> custom_region_id 1 -> 1
# 260006233 eu -> custom_region_id 4 -> 4
# 259980433 eu -> custom_region_id 4 -> 4
# 260016404 eu-ua-2004 -> custom_region_id 2 -> 2
# 34972_Б7361ДЦ_0_1 su -> custom_region_id 12 -> 9
# 3816-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260246099 xx-unknown -> custom_region_id 0 -> 0
# 260592426 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2015_332113569_ACAE eu-ua-2015 -> custom_region_id 1 -> 1
# 259939519 xx-unknown -> custom_region_id 0 -> 0
# 260028198 eu-ua-2015 -> custom_region_id 1 -> 1
# 259944492 xx-unknown -> custom_region_id 0 -> 0
# 260605345 eu-ua-1995 -> custom_region_id 3 -> 3
# T712CA98_0 ru -> custom_region_id 6 -> 6
# 260066837 eu-ua-2015 -> custom_region_id 1 -> 1
# 260236402 eu-ua-2004 -> custom_region_id 2 -> 2
# 260592873 eu -> custom_region_id 4 -> 4
# 18628_А0964ХА_0_1 su -> custom_region_id 12 -> 9
# 260566769 eu-ua-2004 -> custom_region_id 2 -> 2
# O038YK42_0 ru -> custom_region_id 6 -> 6
# 260052420 eu-ua-2015 -> custom_region_id 1 -> 1
# 260026654 eu-ua-2015 -> custom_region_id 1 -> 1
# 260124658 eu-ua-2004 -> custom_region_id 2 -> 2
# 259987173 xx-unknown -> custom_region_id 0 -> 0
# 260752650 eu-ua-1995 -> custom_region_id 3 -> 3
# 260072572 eu-ua-2015 -> custom_region_id 1 -> 1
# 260239207 eu -> custom_region_id 4 -> 4
# 260224520 eu-ua-2004 -> custom_region_id 2 -> 2
# 14729_В0117ХМ_0_1 su -> custom_region_id 12 -> 9
# 260122142 xx-unknown -> custom_region_id 0 -> 0
# 260195309 eu-ua-1995 -> custom_region_id 3 -> 3
# 260028655 eu-ua-2004 -> custom_region_id 2 -> 2
# 88032_О3223ЯТ_0_1 su -> custom_region_id 12 -> 9
# 260066062 eu-ua-2004 -> custom_region_id 2 -> 2
# 260082707 eu -> custom_region_id 4 -> 4
# 260226284 xx-unknown -> custom_region_id 0 -> 0
# 260848486 xx-transit -> custom_region_id 5 -> 5
# option_zero246702869-0 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2004_332142145_AH8AE eu-ua-2004 -> custom_region_id 2 -> 2
# 260232321 eu -> custom_region_id 4 -> 4
# 259987404 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2015_248663055_AA586IA eu-ua-2015 -> custom_region_id 1 -> 1
# 260225427 xx-unknown -> custom_region_id 0 -> 0
# 7887-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 260881750 eu-ua-1995 -> custom_region_id 3 -> 3
# 259965288 eu -> custom_region_id 4 -> 4
# 260947134 eu-ua-1995 -> custom_region_id 3 -> 3
# 260077913 eu-ua-2015 -> custom_region_id 1 -> 1
# 260266326 eu-ua-2004 -> custom_region_id 2 -> 2
# 260599111 eu-ua-2004 -> custom_region_id 2 -> 2
# 260101392 eu -> custom_region_id 4 -> 4
# 260702563 xx-transit -> custom_region_id 5 -> 5
# 260782528 xx-transit -> custom_region_id 5 -> 5
# 260243707 eu -> custom_region_id 4 -> 4
# 3_eu_ua_2015_342089671_BH8AB eu-ua-2015 -> custom_region_id 1 -> 1
# 260019344 eu -> custom_region_id 4 -> 4
# 260224523 eu-ua-2015 -> custom_region_id 1 -> 1
# 260223693 xx-unknown -> custom_region_id 0 -> 0
# 260028615 eu-ua-2015 -> custom_region_id 1 -> 1
# 10914_Г5993КУ_0_1 su -> custom_region_id 12 -> 9
# 8264_П7766ОБ_0_1 su -> custom_region_id 12 -> 9
# 6671-main_0 eu-ua-ordlo-lpr -> custom_region_id 9 -> 8
# 259981426 eu-ua-2004 -> custom_region_id 2 -> 2
# 260245228 eu-ua-2004 -> custom_region_id 2 -> 2
# 260259392 eu-ua-2004 -> custom_region_id 2 -> 2
# 260239713 xx-unknown -> custom_region_id 0 -> 0
# 259817044 eu-ua-1995 -> custom_region_id 3 -> 3
# 260879859 xx-transit -> custom_region_id 5 -> 5
# 259965287 eu -> custom_region_id 4 -> 4
# 259987046 eu-ua-2015 -> custom_region_id 1 -> 1
# 260674721 xx-transit -> custom_region_id 5 -> 5
# 260083056 eu -> custom_region_id 4 -> 4
# 259955685 eu-ua-2015 -> custom_region_id 1 -> 1
# K730CM46_0 ru -> custom_region_id 6 -> 6
# option_zero248591358-0 xx-unknown -> custom_region_id 0 -> 0
# 260568598 eu-ua-2004 -> custom_region_id 2 -> 2
# 260599745 eu -> custom_region_id 4 -> 4
# 260200055 eu-ua-1995 -> custom_region_id 3 -> 3
# 260258698 xx-unknown -> custom_region_id 0 -> 0
# 260553438 xx-unknown -> custom_region_id 0 -> 0
# 261215259 eu-ua-1995 -> custom_region_id 3 -> 3
# 260070923 eu-ua-1995 -> custom_region_id 3 -> 3
# 260029621 xx-unknown -> custom_region_id 0 -> 0
# 260633647 xx-unknown -> custom_region_id 0 -> 0
# K176OB46_0 ru -> custom_region_id 6 -> 6
# 259937985 xx-unknown -> custom_region_id 0 -> 0
# 261181139 xx-transit -> custom_region_id 5 -> 5
# 260568426 eu -> custom_region_id 4 -> 4
# 260049020 eu-ua-2015 -> custom_region_id 1 -> 1
# 260261079 xx-unknown -> custom_region_id 0 -> 0
# option_zero128928988-0 xx-unknown -> custom_region_id 0 -> 0
# 260555411 eu-ua-2004 -> custom_region_id 2 -> 2
# 260227826 eu-ua-2015 -> custom_region_id 1 -> 1
# 260027341 eu-ua-2004 -> custom_region_id 2 -> 2
# H096YX54_0 ru -> custom_region_id 6 -> 6
# 260261266 eu-ua-1995 -> custom_region_id 3 -> 3
# 260564825 eu-ua-2004 -> custom_region_id 2 -> 2
# 12273-main_0 eu-ua-ordlo-dpr -> custom_region_id 8 -> 7
# 259992162 eu -> custom_region_id 4 -> 4
# 260070618 eu -> custom_region_id 4 -> 4
# 260262907 eu-ua-2015 -> custom_region_id 1 -> 1
# 260041727 eu -> custom_region_id 4 -> 4
# 260979851 xx-unknown -> custom_region_id 0 -> 0
# 260261551 eu-ua-2015 -> custom_region_id 1 -> 1
# 260255901 xx-unknown -> custom_region_id 0 -> 0
# 260864327 xx-unknown -> custom_region_id 0 -> 0
# 260051101 eu-ua-2004 -> custom_region_id 2 -> 2
# 260061244 eu-ua-2004 -> custom_region_id 2 -> 2
# 260076423 eu -> custom_region_id 4 -> 4
# 9188_Т8709КУ_2_1 su -> custom_region_id 12 -> 9
# 260247732 eu-ua-2015 -> custom_region_id 1 -> 1
# 261251522 eu-ua-1995 -> custom_region_id 3 -> 3
# 259980431 eu-ua-1995 -> custom_region_id 3 -> 3
# 260282768 eu-ua-2004 -> custom_region_id 2 -> 2
# 260244844 eu-ua-2004 -> custom_region_id 2 -> 2
# 4375_Ш1549ХА_1_1 su -> custom_region_id 12 -> 9
# 260242725 xx-unknown -> custom_region_id 0 -> 0
# 260247502 eu-ua-2004 -> custom_region_id 2 -> 2
# 261015025 eu-ua-1995 -> custom_region_id 3 -> 3
# 260602170 eu -> custom_region_id 4 -> 4
# 259998755 eu-ua-2015 -> custom_region_id 1 -> 1
# 261443927 eu-ua-1995 -> custom_region_id 3 -> 3
# 260062003 eu-ua-2004 -> custom_region_id 2 -> 2
# 260103288 eu -> custom_region_id 4 -> 4
# 260223359 xx-unknown -> custom_region_id 0 -> 0
# 36620_В4643НБ_1_1 su -> custom_region_id 12 -> 9
# 259976530 eu -> custom_region_id 4 -> 4
# 261244978 xx-transit -> custom_region_id 5 -> 5
# 260233308 eu -> custom_region_id 4 -> 4
# option_zero155638042-0 xx-unknown -> custom_region_id 0 -> 0
# 259971002 eu -> custom_region_id 4 -> 4
# 259959920 eu -> custom_region_id 4 -> 4
# 260225660 xx-unknown -> custom_region_id 0 -> 0
# 260281809 eu-ua-2004 -> custom_region_id 2 -> 2
# 260233121 xx-unknown -> custom_region_id 0 -> 0
# 260033709 eu-ua-2004 -> custom_region_id 2 -> 2
# 260674126 eu-ua-1995 -> custom_region_id 3 -> 3
# 260245370 xx-unknown -> custom_region_id 0 -> 0
# 259989431 eu-ua-2004 -> custom_region_id 2 -> 2
# 260798905 xx-transit -> custom_region_id 5 -> 5
# 260230954 eu-ua-2015 -> custom_region_id 1 -> 1
# 260008636 eu-ua-2015 -> custom_region_id 1 -> 1
# option_zero248902299-0 xx-unknown -> custom_region_id 0 -> 0
# 259942864 xx-unknown -> custom_region_id 0 -> 0
# 260248650 eu-ua-2004 -> custom_region_id 2 -> 2
# 260037416 eu -> custom_region_id 4 -> 4
# 260782437 xx-unknown -> custom_region_id 0 -> 0
# 260051172 eu -> custom_region_id 4 -> 4
# 260592955 eu-ua-2004 -> custom_region_id 2 -> 2
# 261338736 eu-ua-1995 -> custom_region_id 3 -> 3
# 260098689 eu-ua-2004 -> custom_region_id 2 -> 2
# 259969210 eu-ua-2015 -> custom_region_id 1 -> 1
# 260244097 eu-ua-1995 -> custom_region_id 3 -> 3
# 260038885 eu-ua-2004 -> custom_region_id 2 -> 2
# 261514524 eu-ua-1995 -> custom_region_id 3 -> 3
# 260603737 eu-ua-1995 -> custom_region_id 3 -> 3
# 260067096 eu-ua-2004 -> custom_region_id 2 -> 2
# 260653659 eu-ua-1995 -> custom_region_id 3 -> 3
# 261143198 eu-ua-1995 -> custom_region_id 3 -> 3
# 260234875 eu -> custom_region_id 4 -> 4
# 260240428 xx-unknown -> custom_region_id 0 -> 0
# 261220207 xx-transit -> custom_region_id 5 -> 5
# 260234122 eu-ua-2015 -> custom_region_id 1 -> 1
# 260775417 eu-ua-1995 -> custom_region_id 3 -> 3
# 3_eu_ua_2015_349904419_AH538AC eu-ua-2015 -> custom_region_id 1 -> 1
# 260223221 xx-unknown -> custom_region_id 0 -> 0
# 54413_А8837ДО_0_1 su -> custom_region_id 12 -> 9
# 260252883 eu-ua-2015 -> custom_region_id 1 -> 1
# 260263451 xx-unknown -> custom_region_id 0 -> 0
# 92849_А1314ХІ_0_1 su -> custom_region_id 12 -> 9
# 260072299 eu-ua-2015 -> custom_region_id 1 -> 1
# 260239464 xx-unknown -> custom_region_id 0 -> 0
# 3_eu_ua_2015_296554786_AI0IE eu-ua-2015 -> custom_region_id 1 -> 1
# 260554121 eu -> custom_region_id 4 -> 4
# 259985148 eu-ua-2004 -> custom_region_id 2 -> 2
# 260000610 eu-ua-2015 -> custom_region_id 1 -> 1
# 259957004 eu -> custom_region_id 4 -> 4
# 260559943 eu-ua-2004 -> custom_region_id 2 -> 2
# 260925122 xx-transit -> custom_region_id 5 -> 5
# 260119473 eu-ua-2015 -> custom_region_id 1 -> 1
# 260086297 eu-ua-2004 -> custom_region_id 2 -> 2
# 259995728 eu-ua-1995 -> custom_region_id 3 -> 3
# 260682656 xx-unknown -> custom_region_id 0 -> 0
# 260228618 xx-unknown -> custom_region_id 0 -> 0
# 260226385 xx-unknown -> custom_region_id 0 -> 0
# 260250746 eu-ua-2004 -> custom_region_id 2 -> 2
# 259978382 eu-ua-2004 -> custom_region_id 2 -> 2
# 260824077 eu -> custom_region_id 4 -> 4
# In test prepared 6351 records

# %%
# definde your parameters
class MyNpClassificator(OptionsDetector):
    def __init__(self, options={}):
        OptionsDetector.__init__(self, options)
        
        # output 2
        self.CLASS_REGION = class_region_custom
        
        # output 3
        self.CLASS_COUNT_LINE = ["0", "1", "2", "3"]
        
        self.EPOCHS           = 200
        self.BATCH_SIZE       = 64
        
        self.HEIGHT         = 64
        self.WEIGHT         = 295

# %%
# initialize region detector.
npClassificator = MyNpClassificator()
npClassificator.prepare(PATH_TO_DATASET, verbose=1)
# Out:
# START PREPARING
# start train build
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-3296507a14fc> in <module>
#       1 # initialize region detector.
#       2 npClassificator = MyNpClassificator()
# ----> 3 npClassificator.prepare(PATH_TO_DATASET, verbose=1)
#
# /var/www/nomeroff-net21/NomeroffNet/OptionsDetector.py in prepare(self, base_dir, verbose)
#     106
#     107         # compile generators
# --> 108         self.train_generator = self.compile_train_generator(
#     109             train_dir, (
#     110                 self.HEIGHT,
#
# /var/www/nomeroff-net21/NomeroffNet/OptionsDetector.py in compile_train_generator(self, train_dir, target_size, batch_size)
#     363             [len(self.CLASS_REGION), len(self.CLASS_COUNT_LINE)])
#     364         print("start train build")
# --> 365         imageGenerator.build_data()
#     366         print("end train build")
#     367         return imageGenerator
#
# /var/www/nomeroff-net21/NomeroffNet/Base/ImgGenerator.py in build_data(self)
#      54             self.discs.append(
#      55                 [
# ---> 56                     np.eye(self.labels_counts[0])[disc[0]],
#      57                     np.eye(self.labels_counts[1])[disc[1]]
#      58                 ]
#
# IndexError: index 12 is out of bounds for axis 0 with size 10

# %%
# train
model = npClassificator.train(LOG_DIR)

# %%
npClassificator.load(os.path.join(LOG_DIR, "./best.pb"))

# %%
npClassificator.test()

# %%
npClassificator.save(RESULT_PATH)

# %%
# %matplotlib inline

# %%
from NomeroffNet.Base.ImgGenerator import ImgGenerator
import torch
import json
import cv2
import matplotlib.pyplot as plt

def show_img(img_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.show()

def small_acc(npClassificator, path_dir="../datasets/options/test", mode_torch="gpu", min_acc=0.75):
    imageGenerator = ImgGenerator(
        path_dir,
        npClassificator.WEIGHT,
        npClassificator.HEIGHT,
        npClassificator.BATCH_SIZE,
        [len(npClassificator.CLASS_REGION), len(npClassificator.CLASS_COUNT_LINE)])
    print("start imageGenerator build")
    imageGenerator.build_data()
    print("end imageGenerator build")
    gen = imageGenerator.pathGenerator()
    for i, (img_paths, inputs, labels) in enumerate(gen, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = torch.from_numpy(inputs)
        if mode_torch == "gpu":
            inputs = inputs.cuda()
        outputs = npClassificator.MODEL(inputs)
        label_reg = torch.from_numpy(labels[0])
        label_cnt = torch.from_numpy(labels[1])
        if mode_torch == "gpu":
            label_reg = label_reg.cuda()
            label_cnt = label_cnt.cuda()
        out_idx_reg = torch.max(outputs[0], 1)[1].cpu().numpy()
        out_idx_line = torch.max(outputs[1], 1)[1].cpu().numpy()
        
        label_idx_reg = torch.max(label_reg, 1)[1].cpu().numpy()
        label_idx_line = torch.max(label_cnt, 1)[1].cpu().numpy()
        
        # check reg
        for o, l, p, tens in zip(out_idx_reg, label_idx_reg, img_paths, outputs[0]):
            if o != l:
                print("[WRONG REGION PREDICTED] pred", o, l, p)
                show_img(p)
            elif tens[l] < min_acc:
                print("[SMALL ACC REGION PREDICTED]  pred", o, l, tens[l], p)
                show_img(p)
        # check line
#         for o, l, p, tens in zip(out_idx_line, label_idx_line, img_paths, outputs[1]):
#             if o != l:
#                 print("[WRONG LINE PREDICTED]  pred", o, l, p)
#                 show_img(p)
#             elif tens[l] < min_acc:
#                 print("[SMALL ACC LINE PREDICTED]  pred", o, l, tens[l], p)
#                 show_img(p)

# %%
small_acc(npClassificator, "../datasets/options/test")

# %%
small_acc(npClassificator, "../datasets/options/train")

# %%
small_acc(npClassificator, "../datasets/options/val")
