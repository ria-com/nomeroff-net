# %% [markdown]
# # This example demonstrate how to train region classification (standart image classification model).

# %%
import os
import sys
import torch
import warnings
from datetime import datetime
from matplotlib import pyplot as plt
warnings.filterwarnings('ignore')

# Nomeroff-Net path
NOMEROFF_NET_DIR = os.path.abspath('../../../../')
sys.path.append(NOMEROFF_NET_DIR)

# %%
plt.rcParams["figure.figsize"] = (10, 10)

# %%
# %matplotlib inline

# %%
# # auto download latest dataset
# from nomeroff_net.tools import modelhub
# info = modelhub.download_dataset_for_model("numberplate_options")
# PATH_TO_DATASET = info["dataset_path"]

# local path dataset
PATH_TO_DATASET = os.path.join(NOMEROFF_NET_DIR, "./data/dataset/OptionsDetector/numberplate_options_example")

PATH_TO_TMP_CUSTOM_DATASET = f'{PATH_TO_DATASET}_tmp_custom'

# %%
PATH_TO_DATASET
# Out:
# '/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example'

# %%
PATH_TO_DATASET
# Out:
# '/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example'

# %%
DATASET_NAME = "options"
VERSION = f"{datetime.now().strftime('%Y_%m_%d')}_pytorch_lightning"

RESULT_PATH = os.path.join(NOMEROFF_NET_DIR, "./data/models/", 'numberplate_{}_{}.ckpt'.format(DATASET_NAME, VERSION))

# %%
RESULT_PATH
# Out:
# '/mnt/data/var/www/nomeroff-net/./data/models/numberplate_options_2022_03_25_pytorch_lightning.ckpt'

# %%
from nomeroff_net.tools import custom_options
from nomeroff_net import OptionsDetector

class_region_custom = [
    ["ru-military","ua-military"],
    "eu-ua-2015",
    "eu-ua-2004",
    "eu-ua-1995",
    "eu",
    "xx-transit",
    "ru",
    "kz",
    "eu-ua-ordlo-dpr",
    "eu-ua-ordlo-lpr",
    "ge",
    "by",
    "su",
    "kg",
    "am"
]

class_count_lines_custom = ["1", "2", "3"]

state_ids_only_labels = ["not filled"]

customOptionsMaker = custom_options.CustomOptionsMaker(
    PATH_TO_DATASET,
    PATH_TO_TMP_CUSTOM_DATASET, 
    OptionsDetector.get_class_region_all(),
    class_region_custom,
    OptionsDetector.get_class_count_lines_all(),
    class_count_lines_custom,
    OptionsDetector.get_class_state_all(),
    state_ids_only_labels,
    items_per_class = 2
)

# %%
customOptionsMaker.make()
# Out:
# Creating path "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom" for custom options
# dir: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example option_dir: train custom_options_sub_dirs[0]: ann
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-2015-2.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-ordlo-lpr.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/kg.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/am.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-1995.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/military-ru.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-2015-3.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-2004.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/ge.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/xx-unknown.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/by.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-ordlo-dpr.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/su.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/eu-ua-2015.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/ru.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/kz.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/xx-transit.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann/military-ua.json
# Labels stat for /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/train/ann
# [((2, 1), 1), ((1, 9), 1), ((1, 13), 1), ((1, 14), 1), ((1, 3), 1), ((1, 4), 1), ((1, 16), 1), ((3, 1), 1), ((1, 2), 1), ((1, 10), 1), ((0, 0), 1), ((1, 11), 1), ((1, 8), 1), ((1, 12), 1), ((1, 1), 1), ((1, 6), 1), ((1, 7), 1), ((1, 5), 1), ((1, 15), 1)]
# In train prepared 18 records
# In train filtered by state_id 1 records
# dir: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example option_dir: val custom_options_sub_dirs[0]: ann
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-2015-2.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-ordlo-lpr.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/kg.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/am.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-1995.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/military-ru.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-2015-3.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-2004.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/ge.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/xx-unknown.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/by.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-ordlo-dpr.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/su.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/eu-ua-2015.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/ru.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/kz.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/xx-transit.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann/military-ua.json
# Labels stat for /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/val/ann
# [((2, 1), 1), ((1, 9), 1), ((1, 13), 1), ((1, 14), 1), ((1, 3), 1), ((1, 4), 1), ((1, 16), 1), ((3, 1), 1), ((1, 2), 1), ((1, 10), 1), ((0, 0), 1), ((1, 11), 1), ((1, 8), 1), ((1, 12), 1), ((1, 1), 1), ((1, 6), 1), ((1, 7), 1), ((1, 5), 1), ((1, 15), 1)]
# In val prepared 18 records
# In val filtered by state_id 1 records
# dir: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example option_dir: test custom_options_sub_dirs[0]: ann
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-2015-2.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-ordlo-lpr.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/kg.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/am.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-1995.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/military-ru.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-2015-3.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-2004.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/ge.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/xx-unknown.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/by.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-ordlo-dpr.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/su.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/eu-ua-2015.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/ru.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/kz.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/xx-transit.json
# /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann/military-ua.json
# Labels stat for /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example/test/ann
# [((2, 1), 1), ((1, 9), 1), ((1, 13), 1), ((1, 14), 1), ((1, 3), 1), ((1, 4), 1), ((1, 16), 1), ((3, 1), 1), ((1, 2), 1), ((1, 10), 1), ((0, 0), 1), ((1, 11), 1), ((1, 8), 1), ((1, 12), 1), ((1, 1), 1), ((1, 6), 1), ((1, 7), 1), ((1, 5), 1), ((1, 15), 1)]
# In test prepared 18 records
# In test filtered by state_id 1 records

# %%
customOptionsMaker.rebalance_count_lines('train', True, True)
# Out:
# Rebalance options stats {'1': {'eu-ua-2015-2.json': {'state_id': 2, 'region_id': 1, 'name': 'eu-ua-2015-2', 'count_lines': 1, 'orientation': 0}}, '0': {'eu-ua-ordlo-lpr.json': {'state_id': 2, 'region_id': 9, 'name': 'eu-ua-ordlo-lpr', 'count_lines': 0, 'orientation': 0}, 'kg.json': {'state_id': 2, 'region_id': 13, 'name': 'kg', 'count_lines': 0, 'orientation': 0}, 'am.json': {'state_id': 2, 'region_id': 14, 'name': 'am', 'count_lines': 0, 'orientation': 0}, 'eu-ua-1995.json': {'state_id': 2, 'region_id': 3, 'name': 'eu-ua-1995', 'count_lines': 0, 'orientation': 0}, 'eu.json': {'state_id': 2, 'region_id': 4, 'name': 'eu', 'count_lines': 0, 'orientation': 0}, 'military-ru.json': {'state_id': 2, 'region_id': 0, 'name': 'military-ru', 'count_lines': 0, 'orientation': 0}, 'eu-ua-2004.json': {'state_id': 2, 'region_id': 2, 'name': 'eu-ua-2004', 'count_lines': 0, 'orientation': 0}, 'ge.json': {'state_id': 2, 'region_id': 10, 'name': 'ge', 'count_lines': 0, 'orientation': 0}, 'by.json': {'state_id': 2, 'region_id': 11, 'name': 'by', 'count_lines': 0, 'orientation': 0}, 'eu-ua-ordlo-dpr.json': {'state_id': 2, 'region_id': 8, 'name': 'eu-ua-ordlo-dpr', 'count_lines': 0, 'orientation': 0}, 'su.json': {'state_id': 2, 'region_id': 12, 'name': 'su', 'count_lines': 0, 'orientation': 0}, 'eu-ua-2015.json': {'state_id': 2, 'region_id': 1, 'name': 'eu-ua-2015', 'count_lines': 0, 'orientation': 0}, 'ru.json': {'state_id': 2, 'region_id': 6, 'name': 'ru', 'count_lines': 0, 'orientation': 0}, 'kz.json': {'state_id': 2, 'region_id': 7, 'name': 'kz', 'count_lines': 0, 'orientation': 0}, 'xx-transit.json': {'state_id': 2, 'region_id': 5, 'name': 'xx-transit', 'count_lines': 0, 'orientation': 0}, 'military-ua.json': {'state_id': 2, 'region_id': 0, 'name': 'military-ua', 'count_lines': 0, 'orientation': 0}}, '2': {'eu-ua-2015-3.json': {'state_id': 2, 'region_id': 1, 'name': 'eu-ua-2015-3', 'count_lines': 2, 'orientation': 0}}}
# Prepare data for count_lines: 1
# Increase class region_id 1 from 1 to 10
# Multiply 1 class data in 10 times and add random 0 items of class
# Make full copy for index 1
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_1_eu-ua-2015-2.png"
# Make full copy for index 2
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_2_eu-ua-2015-2.png"
# Make full copy for index 3
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_3_eu-ua-2015-2.png"
# Make full copy for index 4
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_4_eu-ua-2015-2.png"
# Make full copy for index 5
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_5_eu-ua-2015-2.png"
# Make full copy for index 6
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_6_eu-ua-2015-2.png"
# Make full copy for index 7
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_7_eu-ua-2015-2.png"
# Make full copy for index 8
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_8_eu-ua-2015-2.png"
# Make full copy for index 9
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_9_eu-ua-2015-2.png"
# Add appendix (0 items) for index 10
# Try make duplicate/augmentation for 0 items
# Prepare data for count_lines: 0
# Crop class count_lines 0 to 10
# Prepare data for count_lines: 2
# Increase class region_id 2 from 1 to 10
# Multiply 1 class data in 10 times and add random 0 items of class
# Make full copy for index 1
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_1_eu-ua-2015-3.png"
# Make full copy for index 2
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_2_eu-ua-2015-3.png"
# Make full copy for index 3
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_3_eu-ua-2015-3.png"
# Make full copy for index 4
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_4_eu-ua-2015-3.png"
# Make full copy for index 5
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_5_eu-ua-2015-3.png"
# Make full copy for index 6
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_6_eu-ua-2015-3.png"
# Make full copy for index 7
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_7_eu-ua-2015-3.png"
# Make full copy for index 8
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_8_eu-ua-2015-3.png"
# Make full copy for index 9
# Try make duplicate/augmentation for 1 items
# Make augmented file: "/mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_9_eu-ua-2015-3.png"
# Add appendix (0 items) for index 10
# Try make duplicate/augmentation for 0 items
# 1

# %%
class MyNpClassificator(OptionsDetector):
    def __init__(self):
        OptionsDetector.__init__(self)
        
        # outputs 2
        #self.class_region = class_region_custom
        self.class_region = [
            "military",
            "eu-ua-2015",
            "eu-ua-2004",
            "eu-ua-1995",
            "eu",
            "xx-transit",
            "ru",
            "kz",
            "eu-ua-ordlo-dpr",
            "eu-ua-ordlo-lpr",
            "ge",
            "by",
            "su",
            "kg",
            "am"
        ]
        
        # output 3
        self.count_lines = class_count_lines_custom
        
        self.epochs           = 2
        self.batch_size       = 2
        
        # count gpu for train
        self.gpus = torch.cuda.device_count()
        
        self.height         = 64
        self.width         = 295

# %%
# initialize region detector.
npClassificator = MyNpClassificator()
npClassificator.prepare(PATH_TO_TMP_CUSTOM_DATASET, verbose=1, num_workers=1)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# START PREPARING
# 100%|██████████| 30/30 [00:00<00:00, 240.90it/s]
# 100%|██████████| 18/18 [00:00<00:00, 390.82it/s]
# 100%|██████████| 18/18 [00:00<00:00, 431.15it/s]
# DATA PREPARED

# %%
# train
lr_finder = npClassificator.tune()

# Plot with
fig = lr_finder.plot(suggest=True)
fig.show()
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HBox(children=(FloatProgress(value=0.0, description='Finding best initial lr', max=3.0, style=ProgressStyle(de…
# /usr/local/lib/python3.8/site-packages/pytorch_lightning/loops/optimization/closure.py:35: LightningDeprecationWarning: One of the returned values {'progress_bar', 'log'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   rank_zero_deprecation(
# Restoring states from the checkpoint path at /mnt/data/var/www/nomeroff-net/examples/ju/train/classification/lr_find_temp_model_0440515d-9e9f-4070-8cb4-d90e09fa5462.ckpt
# Failed to compute suggesting for `lr`. There might not be enough points.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/pytorch_lightning/tuner/lr_finder.py", line 176, in suggestion
#     min_grad = np.gradient(loss).argmin()
#   File "<__array_function__ internals>", line 5, in gradient
#   File "/usr/local/lib64/python3.8/site-packages/numpy/lib/function_base.py", line 1041, in gradient
#     raise ValueError(
# ValueError: Shape of array too small to calculate a numerical gradient, at least (edge_order + 1) elements are required.
# Failed to compute suggesting for `lr`. There might not be enough points.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/pytorch_lightning/tuner/lr_finder.py", line 176, in suggestion
#     min_grad = np.gradient(loss).argmin()
#   File "<__array_function__ internals>", line 5, in gradient
#   File "/usr/local/lib64/python3.8/site-packages/numpy/lib/function_base.py", line 1041, in gradient
#     raise ValueError(
# ValueError: Shape of array too small to calculate a numerical gradient, at least (edge_order + 1) elements are required.
# Found lr: None

# %%
# train
model = npClassificator.train()
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /usr/local/lib/python3.8/site-packages/pytorch_lightning/core/datamodule.py:469: LightningDeprecationWarning: DataModule.setup has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.setup.
#   rank_zero_deprecation(
#
#    | Name            | Type        | Params
# -------------------------------------------------
# 0  | resnet          | Sequential  | 2.8 M
# 1  | dropout_reg     | Dropout     | 0
# 2  | fc1_reg         | Linear      | 10.0 M
# 3  | fc2_reg         | Linear      | 131 K
# 4  | batch_norm_reg  | BatchNorm1d | 1.0 K
# 5  | fc3_reg         | Linear      | 3.9 K
# 6  | dropout_line    | Dropout     | 0
# 7  | fc1_line        | Linear      | 10.0 M
# 8  | fc2_line        | Linear      | 131 K
# 9  | batch_norm_line | BatchNorm1d | 1.0 K
# 10 | fc3_line        | Linear      | 771
# -------------------------------------------------
# 23.0 M    Trainable params
# 0         Non-trainable params
# 23.0 M    Total params
# 91.904    Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# /usr/local/lib/python3.8/site-packages/pytorch_lightning/core/datamodule.py:469: LightningDeprecationWarning: DataModule.teardown has already been called, so it will not be called again. In v1.6 this behavior will change to always call DataModule.teardown.
#   rank_zero_deprecation(

# %%
npClassificator.prepare(PATH_TO_DATASET, verbose=1)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# START PREPARING
# 100%|██████████| 19/19 [00:00<00:00, 127.37it/s]
# 100%|██████████| 19/19 [00:00<00:00, 304.97it/s]
# 100%|██████████| 19/19 [00:00<00:00, 317.36it/s]
# DATA PREPARED

# %%
npClassificator.save(RESULT_PATH)
# Out:
# model save to /mnt/data/var/www/nomeroff-net/./data/models/numberplate_options_2022_03_25_pytorch_lightning.ckpt

# %% [markdown]
# # Classification Report

# %%
npClassificator.load(RESULT_PATH)
# Out:
# NPOptionsNet(
#   (resnet): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (dropout_reg): Dropout(p=0.2, inplace=False)
#   (fc1_reg): Linear(in_features=19456, out_features=512, bias=True)
#   (fc2_reg): Linear(in_features=512, out_features=256, bias=True)
#   (batch_norm_reg): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3_reg): Linear(in_features=256, out_features=15, bias=True)
#   (dropout_line): Dropout(p=0.2, inplace=False)
#   (fc1_line): Linear(in_features=19456, out_features=512, bias=True)
#   (fc2_line): Linear(in_features=512, out_features=256, bias=True)
#   (batch_norm_line): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3_line): Linear(in_features=256, out_features=3, bias=True)
# )

# %%
from nomeroff_net.data_loaders import ImgGenerator
from sklearn.metrics import classification_report
import torch

def options_classification_report(npClassificator, 
                                  path_dir=os.path.join(PATH_TO_TMP_CUSTOM_DATASET, "test"), 
                                  mode_torch="gpu" if torch.cuda.device_count() else "cpu"):
    imageGenerator = ImgGenerator(
        path_dir,
        npClassificator.width,
        npClassificator.height,
        npClassificator.batch_size,
        [len(npClassificator.class_region), len(npClassificator.count_lines)])
    imageGenerator.build_data()
    gen = imageGenerator.path_generator()
    
    out_idx_reg_all = []
    out_idx_line_all = []
    label_idx_reg_all = []
    label_idx_line_all = []
    for i, (img_paths, inputs, labels) in enumerate(gen, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = torch.from_numpy(inputs)
        if mode_torch == "gpu":
            inputs = inputs.cuda()
            npClassificator.model.cuda()
        with torch.no_grad():
            outputs = npClassificator.model(inputs)
        label_reg = torch.from_numpy(labels[0])
        label_cnt = torch.from_numpy(labels[1])
        if mode_torch == "gpu":
            label_reg = label_reg.cuda()
            label_cnt = label_cnt.cuda()
        
        out_idx_reg = torch.max(outputs[0], 1)[1].cpu().numpy()
        out_idx_line = torch.max(outputs[1], 1)[1].cpu().numpy()
        
        label_idx_reg = torch.max(label_reg, 1)[1].cpu().numpy()
        label_idx_line = torch.max(label_cnt, 1)[1].cpu().numpy()
        
        out_idx_reg_all.extend(out_idx_reg)
        out_idx_line_all.extend(out_idx_line)
        label_idx_reg_all.extend(label_idx_reg)
        label_idx_line_all.extend(label_idx_line)
    #print("npClassificator.class_region", npClassificator.class_region)
    print("\n\nclass region classification report:")
    print(classification_report(label_idx_reg_all, 
                                out_idx_reg_all, 
                                target_names=npClassificator.get_class_region_for_report()))
    print("\n\ncount lines classification report:")
    print(classification_report(label_idx_line_all, 
                                out_idx_line_all, 
                                target_names=npClassificator.count_lines))

# %%
options_classification_report(npClassificator, path_dir=os.path.join(PATH_TO_TMP_CUSTOM_DATASET, "test"))
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 9561.48it/s]
# class region classification report:
#                  precision    recall  f1-score   support
#
#        military       0.00      0.00      0.00         2
#      eu-ua-2015       1.00      0.33      0.50         3
#      eu-ua-2004       0.00      0.00      0.00         1
#      eu-ua-1995       0.00      0.00      0.00         1
#              eu       0.00      0.00      0.00         1
#      xx-transit       0.00      0.00      0.00         1
#              ru       0.00      0.00      0.00         1
#              kz       0.00      0.00      0.00         1
# eu-ua-ordlo-dpr       0.00      0.00      0.00         1
# eu-ua-ordlo-lpr       0.00      0.00      0.00         1
#              ge       0.00      0.00      0.00         1
#              by       0.00      0.00      0.00         1
#              su       0.00      0.00      0.00         1
#              kg       0.00      0.00      0.00         1
#              am       0.00      0.00      0.00         1
#
#        accuracy                           0.06        18
#       macro avg       0.07      0.02      0.03        18
#    weighted avg       0.17      0.06      0.08        18
#
#
#
# count lines classification report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18

# %% [markdown]
# # Check small accuracy images

# %%
npClassificator.load(RESULT_PATH)
# Out:
# NPOptionsNet(
#   (resnet): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (dropout_reg): Dropout(p=0.2, inplace=False)
#   (fc1_reg): Linear(in_features=19456, out_features=512, bias=True)
#   (fc2_reg): Linear(in_features=512, out_features=256, bias=True)
#   (batch_norm_reg): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3_reg): Linear(in_features=256, out_features=15, bias=True)
#   (dropout_line): Dropout(p=0.2, inplace=False)
#   (fc1_line): Linear(in_features=19456, out_features=512, bias=True)
#   (fc2_line): Linear(in_features=512, out_features=256, bias=True)
#   (batch_norm_line): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc3_line): Linear(in_features=256, out_features=3, bias=True)
# )

# %%
# %matplotlib inline

# %%
from nomeroff_net.data_loaders import ImgGenerator
import torch
import json
import cv2
import matplotlib.pyplot as plt

def show_img(img_path):
    img = cv2.imread(img_path)
    img = img[..., ::-1]
    plt.imshow(img)
    plt.show()
    
def mark_for_moderation(p):
    json_filepath = p.replace('/img/','/ann/').replace('.png','.json')
    item_data = json.load(open(json_filepath, 'r'))
    if not item_data['moderation']:
        item_data['moderation'] = { "moderatedBy": "dimabendera" }
    item_data['moderation']["isModerated"] = 0
    with open(json_filepath, "w") as json_file:
        json.dump(item_data, json_file)    

def small_acc(npClassificator, 
              path_dir=os.path.join(PATH_TO_TMP_CUSTOM_DATASET, "test"), 
              mode_torch="gpu" if torch.cuda.device_count() else "cpu", 
              min_acc=0.75):
    imageGenerator = ImgGenerator(
        path_dir,
        npClassificator.width,
        npClassificator.height,
        npClassificator.batch_size,
        [len(npClassificator.class_region), len(npClassificator.count_lines)])
    print("start imageGenerator build")
    imageGenerator.build_data()
    print("end imageGenerator build")
    gen = imageGenerator.path_generator()

# (npClassificator, 
#               path_dir=os.path.join(PATH_TO_DATASET, "test"), 
#               mode_torch="gpu", 
#               min_acc=0.75):
#     imageGenerator = ImgGenerator(
#         path_dir,
#         npClassificator.width,
#         npClassificator.height,
#         npClassificator.batch_size,
#         [len(npClassificator.class_region), len(npClassificator.count_lines)])
#     print("start imageGenerator build")
#     imageGenerator.build_data()
#     print("end imageGenerator build")
#     gen = imageGenerator.path_generator()
    cnt = 0
    cnt_all = 0
    for i, (img_paths, inputs, labels) in enumerate(gen, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs = torch.from_numpy(inputs)
        if mode_torch == "gpu":
            inputs = inputs.cuda()
        outputs = npClassificator.model(inputs)
        label_reg = torch.from_numpy(labels[0])
        label_cnt = torch.from_numpy(labels[1])
        if mode_torch == "gpu":
            label_reg = label_reg.cuda()
            label_cnt = label_cnt.cuda()
        out_idx_reg = torch.max(outputs[0], 1)[1].cpu().numpy()
        out_idx_line = torch.max(outputs[1], 1)[1].cpu().numpy()
        
        label_idx_reg = torch.max(label_reg, 1)[1].cpu().numpy()
        label_idx_line = torch.max(label_cnt, 1)[1].cpu().numpy()
        
        # check reg
        for o, l, p, tens in zip(out_idx_reg, label_idx_reg, img_paths, outputs[0]):
            cnt_all += 1
            if o != l:
                print("[WRONG REGION PREDICTED] pred {}[{}] -> {}[{}] source: {}".format(o,npClassificator.class_region[o], l, npClassificator.class_region[l], p))
                #mark_for_moderation(p)
                show_img(p)
                cnt += 1
    print("Wrong detection: {} numberplates of {}".format(cnt, cnt_all))
#             elif tens[l] < min_acc:
#                 print("[SMALL ACC REGION PREDICTED]  pred", o, l, tens[l], p)
#                 show_img(p)
        # check line
#         for o, l, p, tens in zip(out_idx_line, label_idx_line, img_paths, outputs[1]):
#             if o != l:
#                 print("[WRONG LINE PREDICTED]  pred", o, l, p)
#                 show_img(p)
#             elif tens[l] < min_acc:
#                 print("[SMALL ACC LINE PREDICTED]  pred", o, l, tens[l], p)
#                 show_img(p)

# %%
small_acc(npClassificator, os.path.join(PATH_TO_TMP_CUSTOM_DATASET, "test"))
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 8819.80it/s]
# start imageGenerator build
# end imageGenerator build
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 7[kz] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/kz.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 12[su] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/su.png
# [WRONG REGION PREDICTED] pred 0[military] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu-ua-2015.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 4[eu] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 8[eu-ua-ordlo-dpr] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu-ua-ordlo-dpr.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 10[ge] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/ge.png
# [WRONG REGION PREDICTED] pred 3[eu-ua-1995] -> 13[kg] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/kg.png
# [WRONG REGION PREDICTED] pred 3[eu-ua-1995] -> 5[xx-transit] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/xx-transit.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 0[military] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/military-ru.png
# [WRONG REGION PREDICTED] pred 13[kg] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 2[eu-ua-2004] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu-ua-2004.png
# [WRONG REGION PREDICTED] pred 12[su] -> 14[am] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/am.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 0[military] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/military-ua.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 11[by] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/by.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 3[eu-ua-1995] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu-ua-1995.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 6[ru] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/ru.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 9[eu-ua-ordlo-lpr] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/test/img/eu-ua-ordlo-lpr.png
# Wrong detection: 17 numberplates of 18

# %%
#small_acc(npClassificator, os.path.join(PATH_TO_TMP_CUSTOM_DATASET, "train"))
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 12852.82it/s]
# start imageGenerator build
# end imageGenerator build
# [WRONG REGION PREDICTED] pred 0[military] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_4_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 0[military] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/military-ru.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 3[eu-ua-1995] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/eu-ua-1995.png
# [WRONG REGION PREDICTED] pred 9[eu-ua-ordlo-lpr] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_7_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 4[eu] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_9_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 13[kg] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_2_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 0[military] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/eu-ua-2015.png
# [WRONG REGION PREDICTED] pred 3[eu-ua-1995] -> 5[xx-transit] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/xx-transit.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 11[by] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/by.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_8_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 7[kz] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/kz.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 6[ru] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/ru.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 12[su] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/su.png
# [WRONG REGION PREDICTED] pred 13[kg] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_9_eu-ua-2015-3.png
# [WRONG REGION PREDICTED] pred 13[kg] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 13[kg] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_1_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 0[military] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_5_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 0[military] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/military-ua.png
# [WRONG REGION PREDICTED] pred 3[eu-ua-1995] -> 13[kg] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/kg.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_3_eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 4[eu] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/train/img/aug_6_eu-ua-2015-2.png
# Wrong detection: 21 numberplates of 30

# %%
#small_acc(npClassificator, os.path.join(PATH_TO_TMP_CUSTOM_DATASET, "val"))
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 14896.90it/s]
# start imageGenerator build
# end imageGenerator build
# [WRONG REGION PREDICTED] pred 0[military] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu-ua-2015.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 2[eu-ua-2004] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu-ua-2004.png
# [WRONG REGION PREDICTED] pred 3[eu-ua-1995] -> 5[xx-transit] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/xx-transit.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 8[eu-ua-ordlo-dpr] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu-ua-ordlo-dpr.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 6[ru] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/ru.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 9[eu-ua-ordlo-lpr] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu-ua-ordlo-lpr.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 10[ge] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/ge.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 3[eu-ua-1995] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu-ua-1995.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 11[by] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/by.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 0[military] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/military-ru.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 4[eu] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu.png
# [WRONG REGION PREDICTED] pred 3[eu-ua-1995] -> 13[kg] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/kg.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 7[kz] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/kz.png
# [WRONG REGION PREDICTED] pred 7[kz] -> 12[su] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/su.png
# [WRONG REGION PREDICTED] pred 13[kg] -> 1[eu-ua-2015] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/eu-ua-2015-2.png
# [WRONG REGION PREDICTED] pred 2[eu-ua-2004] -> 0[military] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/military-ua.png
# [WRONG REGION PREDICTED] pred 12[su] -> 14[am] source: /mnt/data/var/www/nomeroff-net/./data/dataset/OptionsDetector/numberplate_options_example_tmp_custom/val/img/am.png
# Wrong detection: 17 numberplates of 18
